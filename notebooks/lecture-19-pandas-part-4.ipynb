# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
#
#   /* Slide titles, px for the same reason. Every heading and every card in a
#      deck sits inside `.jp-RenderedHTMLCommon`, which JupyterLab sizes at 14px
#      -- NOT the 26px this theme puts on the slide. So the `1.45em` this rule
#      used to carry rendered at 20.3px, and the lecture title's `1.35em` at
#      18.9px, i.e. the title card came out SMALLER than the slide titles under
#      it and both sat within a couple of px of the 18px code. */
#   --dma-title-size: 22px;
#
#   /* Body prose. This is JupyterLab's own variable rather than a `--dma-` one:
#      `.jp-RenderedHTMLCommon` sizes itself from it, and everything inside a
#      rendered markdown cell inherits from there -- paragraphs, list items,
#      table cells, blockquotes. Setting it here lifts all of them at once, and
#      scoped to `.reveal` it changes the deck only, never the notebook editor.
#      It also gives the theme's remaining `em` values something sensible to
#      anchor to: inline code at `0.92em` and the small-caps card labels scale
#      with the prose instead of against JupyterLab's 14px default. The sizes
#      that must not move with it -- slide titles, code, output -- are all in px
#      above. */
#   --jp-content-font-size1: 17px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: var(--dma-title-size) !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:18px;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">19</span>
#     <span style="font-size:24px;font-weight:800;line-height:1.15;">Pandas Part 4</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">1 content slides &nbsp;&middot;&nbsp; 20 live demos &nbsp;&middot;&nbsp; 3 in-class exercises</div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     String Methods: Using the Lower Method
#   </div>
# </div>
#
# The code below creates a dataframe and then uses the lower method to convert its first column to lower case.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame([['A.','c.'],['B.','d.']])
# convert first column to lower case
df[0]=df[0].str.lower()
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     String Methods: Using the Upper and Replace Methods
#   </div>
# </div>
#
# The code below converts the second column of the dataframe to upper case, and then converts the period to an exclamation point in that column.

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame([['A.','c.'],['B.','d.']])
df[0]=df[0].str.lower()
# chained operations:
# convert second column to upper case
# and then replace the period with an exclamation point
df[1]=df[1].str.upper().str.replace('.','!')
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Splitting Data in a Column
#   </div>
# </div>
#
# Here we use str.split to split the URL column of a dataframe. The expand option creates new columns and returns a DataFrame; otherwise you get lists in a Series.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame([['New York University', 'https://nyu.edu' ],
                   ['Apple', 'http://apple.com']],
              columns=['Name', 'URL'])
print(df)
print()
# expand into separate columns
tmp = df['URL'].str.split('://', expand=True)
print(tmp)
print(type(tmp))
print()

# keep as lists in a series
tmp2 = df['URL'].str.split('://')
print(tmp2)
print(type(tmp2))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Adding the Columns Back
#   </div>
# </div>
#
# Now we can add the new columns to the original dataframe.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame([['New York University', 'https://nyu.edu' ],
                   ['Apple', 'http://apple.com']],
              columns=['Name', 'URL'])
# expand into separate columns
tmp = df['URL'].str.split('://', expand=True)
# keep as lists in a series
# tmp = df['URL'].str.split('://')

# add back to original DataFrame
df[['protocol','domain']]=tmp
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Global Replacement in a DataFrame
#   </div>
# </div>
#
# Replace all of the instances of "foo" with "qux" anywhere in the dataframe. And replace all of the instances of -1 with 100.

# %%
import pandas as pd
import numpy as np
# here is a another toy dataframe
df = pd.DataFrame([['foo', -1],
                   ['foo', 12],
                   ['bar', 3]], columns=['a', 'b'])
print(df) # before
df=df.replace('foo','qux')
df=df.replace(-1,100)
print(df) # after

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Methods for Dealing with Missing Data (1)
#   </div>
# </div>
#
# Below, we create a dataframe containing some missing data.
#
# One approach is to remove columns with missing data. This is far from ideal, but this is what we are doing here.

# %%
# another toy dataframe
import numpy as np
import pandas as pd
df = pd.DataFrame(np.arange(12).reshape((3, 4)),  columns=list('abcd'))
# make two of the values missing
df.loc[1, 'd'] = np.nan
df.loc[2, 'c'] = np.nan
print(df)
print()
# one approach: ignoring the columns with missing data
df=df.dropna(axis=1)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Methods for Dealing with Missing Data (2)
#   </div>
# </div>
#
# You could also drop the rows containing missing data. Again, not ideal

# %%
# another toy dataframe
import numpy as np
import pandas as pd
df = pd.DataFrame(np.arange(12).reshape((3, 4)),  columns=list('abcd'))
# make two of the values missing
df.loc[1, 'd'] = np.nan
df.loc[2, 'c'] = np.nan
print(df)
df.dropna(axis=0, inplace=True)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Imputation
#   </div>
# </div>
#
# In statistics, the process of filling in missing data, and of dealing with missing data in general, is called "imputation." This is a very complex topic and whole courses and [books](https://stefvanbuuren.name/fimd/) are concerned with the topic.
#
# The simplest imputation approach is to replace each missing value with the column's mean. In the example below, we do this using a dictionary.
#
# Mean imputation only works with numerical data, not categorical data. And it makes little sense for binary categorical data (like gender, for instance.)

# %%
# another toy dataframe
import numpy as np
import pandas as pd
df = pd.DataFrame(np.arange(12).reshape((3, 4)),  columns=list('abcd'))
# make two of the values missing
df.loc[1, 'd'] = np.nan
df.loc[2, 'c'] = np.nan

print("Before Mean Imputation:")
print(df)
# sets missing values in each column to the mean of that column
# mean computation ignores missing values
print("After Mean Imputation")
df.fillna({'c':df['c'].mean(),'d':df['d'].mean()},inplace=True)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     &quot;Hot Deck&quot; Imputation
#   </div>
# </div>
#
# ["Hot deck"](https://pubmed.ncbi.nlm.nih.gov/21743766/) imputation just fills missing values with the previous non-missing value in the column. This can be reasonable if you expect similar observations (that is, rows) to be near one another in the list or if you have sorted them so that this is the case.
#
# In pandas, you can use the ffill (forward fill) method to accomplish this. There is also bfill which files with the next non-missing observation rather than the previous one.

# %%
# another toy dataframe
import numpy as np
import pandas as pd
df = pd.DataFrame(np.arange(12).reshape((3, 4)),  columns=list('abcd'))
# make two of the values missing
df.loc[1, 'd'] = np.nan
df.loc[2, 'c'] = np.nan

print("Before Hot Deck Imputation:")
print(df)
# sets missing values in each column to the mean of that column
# mean computation ignores missing values
print("After Hot Deck Imputation (forward)")
df2=df.ffill()
print(df2)
print("After Hot Deck Imputation (backward)")
df3=df.bfill()
print(df3)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Binning
#   </div>
# </div>
#
# Perhaps you have a lot of continuous data. It may be useful to categorize that data into bins for easier analysis or reporting.
#
# To do this, you use pd.cut(data,bins,labels=labels)
#
# Where the bins are the boundaries of the bins as a list.
#
# labels can be used to specify text labels for each bin.
#
# This creates a categories object which can be counted with the value\_counts method.
#
# In the example below, we generate 100 random numbers between 60 and 100 representing student grades. We then bin them into letter grades where 60-69 is a D, 70-79 is a C, etc. We can then count the categories using value\_counts.

# %%
import pandas as pd
import numpy as np
# generate 100 random numbers between 60 and 100 (simulating student grades)
scores=np.random.randint(60,101,size=100)
# represents 60-69 (D), 70-79 (C), 80-89 (B), 90-100 (A)
# upper is inclusive, lower is exclusive
bins=[59,69,79,89,100]
gradelabels=['D','C','B','A' ]
print(scores)
grades=pd.cut(scores,bins, labels=gradelabels)
print(grades)
print(type(grades))
print(grades.value_counts())

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Binning the Weight and Height File
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <b style="color:#b26a00;font-size:0.72em;">Exercise Link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;
#                  font-size:0.72em;color:#6b6478;">&lt;PrairieLearn URL here&gt;</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Renaming Columns
#   </div>
# </div>
#
# The code below creates a dataframe and then transforms all of the column names to upper case using the rename function.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(9).reshape((3, 3)),
                 columns = ['a', 'b', 'c'])
print(df)
df.rename(columns=str.upper,inplace=True)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Renaming Columns v2
#   </div>
# </div>
#
# The code below creates a dataframe and then transforms all of the column names to upper case by resetting the columns attribute using map.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(9).reshape((3, 3)),
                 columns = ['a', 'b', 'c'])
print(df)
df.columns=df.columns.map(str.upper)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Renaming Columns v3
#   </div>
# </div>
#
# The code below creates a dataframe and then replaces the row names using a list of numbers. Then it replaces the column names with a list of words.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.arange(9).reshape((3, 3)),
                 columns = ['a', 'b', 'c'])
print(df)
df.index=[5,7,9]
df.columns=["Pluto", "Mickey", "Goofy"]
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Testing a Dataframe
#   </div>
# </div>
#
# In the code below, we create a dataframe. We then create another dataframe that has Boolean values depending whether the values in the first dataframe are above 40.
#
# After this, we see if any of the values in each of the columns are True, and then whether any of the values in each of the rows are true.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame([[2, 3], [1, 50], [20, 4], [3, 45]])
print(df)
over40=(df>40)
print(over40)
print(over40.any())
print(over40.any(axis=1))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Testing and Updating a Dataframe
#   </div>
# </div>
#
# In the code below, we create a dataframe.
#
# First, we find the rows with values in their second column over 10.
#
# Then we replace all of those values in the second column that are over 10 with 10. This is sometimes called top-coding.

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame([[2, 3], [1, 50], [20, 4], [3, 45]])
print("Original dataframe:")
print(df)
print("Rows with values of the Second Column over 10:")
print(df[df[1]>10])
df.loc[df[1]>10,1] = 10
print("Dataframe with replaced values:")
print(df)

# %% [markdown]
# ## Type Conversion
#
# To convert columns from one type to another, use:
#
# - astype(newType)
# - pd.to\_numeric(colName)
# - pd.to\_datetime(colName)
#
# The last two allow ignoring type conversion errors.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Reformatting Data
#   </div>
# </div>
#
# We read in a dataframe below. Then we remove the dollar signs and convert to numeric, coercing anything that doesn't convert (e.g. a string) to NaN.

# %%
import pandas as pd
data = [['2009', '$500'],
        ['2010', '$1,234'],
        ['2011', 'bad data'],
        ['2012', '$2,507']]
df = pd.DataFrame(data , columns=['date', 'total'])
print("Original Dataframe:")
print(df)
df['total'] = df['total'].str.replace('$', '', regex=False)
df['total'] = df['total'].str.replace(',', '',regex=False)
df['total'] = pd.to_numeric(df['total'],errors='coerce')
print("Modified Dataframe:")
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Converting Strings to Datetime Objects
#   </div>
# </div>
#
# Pandas has datetime objects. In the code below, we convert two strings to datetime objects, and then we can use accessors.

# %%
import pandas as pd
s = pd.Series(['Jan 7, 2014', 'May 29, 1993'])
s= pd.to_datetime(s)
print(s)
print("Numeric months:")
print(s.dt.month)
print("Month Names:")
print(s.dt.month_name())
print("Numeric Week of the year:")
print(s.dt.isocalendar().week)
print("Day of the year:")
print(s.dt.dayofyear)
print("Day of the week:")
print(s.dt.day_name())

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Joining Dataframes
#   </div>
# </div>
#
# The pandas merge method joins data from one DataFrame with another based on common column values. The default result is the intersection of rows with matching column values, with all columns included, as in the example below. This is called an inner join.
#
# Three ways to do the same inner join are shown.

# %%
import pandas as pd
a = pd.DataFrame([[2, 20], [4, 40], [6, 60], [8, 80]],
                 columns=['k', 'col1'])
b = pd.DataFrame([[4, 2], [4, 3], [8, 7], [10,6]],
                 columns=['k', 'col2'])
print("First Dataframe:")
print(a)
print("Second Dataframe:")
print(b)
print("Inner Join: Method 1")
print(pd.merge(a,b,on='k'))
print("Inner Join: Method 2")
print(a.merge(b,on='k'))
print("Inner Join: Method 3")
print(b.merge(a,on='k'))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Types of Merges (Joins)
#   </div>
# </div>
#
# The following are the main types of joins in use:
#
# - 'left': include all keys from the first (left) DataFrame, even if they don't exist in second (right)
# - 'right': include all keys from the second (right) DataFrame, even if they don't exist in first (left)
# - 'outer': union of keys from both DataFrames
# - 'inner': intersection of keys from both DataFrames (default)
#
# We will see all of these again when we study SQL.

# %%
import pandas as pd
a = pd.DataFrame([[2, 20], [4, 40], [6, 60], [8, 80]],
                 columns=['k', 'col1'])
b = pd.DataFrame([[4, 2], [4, 3], [8, 7], [10,6]],
                 columns=['k', 'col2'])
print("First Dataframe:")
print(a)
print("Second Dataframe:")
print(b)
print("Outer Join:")
print(pd.merge(a,b,on='k',how='outer'))
print("Left Join:")
print(pd.merge(a,b,on='k',how='left'))
print("Right Join:")
print(pd.merge(a,b,on='k',how='right'))
print("Inner Join:")
print(pd.merge(a,b,on='k',how='inner'))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Join Exercise
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713057" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       First exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713057</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Cross Join Exercise
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713057" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Second exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713057</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     The Pandas concat Method for Appending Dataframes
#   </div>
# </div>
#
# If you have two data frames with the same column names, you can append one of them to the other using the pandas concat method as shown in the code example below.

# %%
import pandas as pd
import numpy as np
d1 = pd.DataFrame(np.arange(9).reshape((3, 3)),
                columns=list('abc'))
d2 = pd.DataFrame(np.arange(10, 19).reshape((3, 3)),
                columns=list('abc'))
print(d1)
print(d2)
d3=pd.concat([d1,d2])
print(d3)
d3.index=range(6) # resetting the index
print(d3)

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 19</div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Pandas Part 4
#   </div>
# </div>
