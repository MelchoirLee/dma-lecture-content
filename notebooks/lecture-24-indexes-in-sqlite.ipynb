# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
#
#   /* Slide titles, px for the same reason. Every heading and every card in a
#      deck sits inside `.jp-RenderedHTMLCommon`, which JupyterLab sizes at 14px
#      -- NOT the 26px this theme puts on the slide. So the `1.45em` this rule
#      used to carry rendered at 20.3px, and the lecture title's `1.35em` at
#      18.9px, i.e. the title card came out SMALLER than the slide titles under
#      it and both sat within a couple of px of the 18px code. */
#   --dma-title-size: 22px;
#
#   /* Body prose. This is JupyterLab's own variable rather than a `--dma-` one:
#      `.jp-RenderedHTMLCommon` sizes itself from it, and everything inside a
#      rendered markdown cell inherits from there -- paragraphs, list items,
#      table cells, blockquotes. Setting it here lifts all of them at once, and
#      scoped to `.reveal` it changes the deck only, never the notebook editor.
#      It also gives the theme's remaining `em` values something sensible to
#      anchor to: inline code at `0.92em` and the small-caps card labels scale
#      with the prose instead of against JupyterLab's 14px default. The sizes
#      that must not move with it -- slide titles, code, output -- are all in px
#      above. */
#   --jp-content-font-size1: 17px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: var(--dma-title-size) !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:18px;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">24</span>
#     <span style="font-size:24px;font-weight:800;line-height:1.15;">Indexes in SQLite</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">1 content slides &nbsp;&middot;&nbsp; 12 live demos</div>
# </div>

# %% [markdown]
# ## Indexes in SQLite
#
# This notebook contains a simple demonstration of the performance boost that can be associated with creating an index in SQLite. An index on one or more columns in a database can speed up searching on those columns. Of course, an index is not free; it takes up more space. So we have an example of the familiar space/time tradeoff in computer science.
#
# Another cost of an index is that it takes a little longer to insert items in the affected columns because the index must be updated as well as the columns themselves.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Setting Up a Test Database
#   </div>
# </div>
#
# The following is the usual setup for SQLite. Here we create a test database which we call index\_test.db.

# %%
import sqlite3
import pandas as pd
import os
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Query Functions
#   </div>
# </div>
#
# The code below contains some python functions to execute queries.

# %%
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a table
#   </div>
# </div>
#
# Here we create a test table with two columns, i which is the primary key and v which will be a random value we will insert in each row.
#
# There is no index yet for column v, but we will add one soon.

# %%
import sqlite3
import pandas as pd
import os
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Inserting Data
#   </div>
# </div>
#
# Now we insert 100,000 random numbers between 1 and 100,000 into the table. We construct a really long query to do that.

# %%
import sqlite3
import pandas as pd
import os
import random
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying the Data Without an Index
#   </div>
# </div>
#
# Now we create a query to find all of the numbers between 100 and 110 inclusive. This requires searching  the entire table. We keep track of how long it takes.
#
# Before running the search, we can ask SQLite how it plans to do it using "EXPLAIN QUERY PLAN".

# %%
import sqlite3
import pandas as pd
import os
import random
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)
read=pd.read_sql_query('explain query plan select v from test where v>=100 and v<=110',conn)
print(read)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Running the Query
#   </div>
# </div>
#
# Now we actually run the query, and time it.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)

# record start time
start = time.time_ns()

x=pd.read_sql_query("select * from test where v>=100 and v<=110",conn)
print(x)
# record end time
end = time.time_ns()

# print elapsed time in seconds
print(f"Elapsed time using process_time(): {end - start:,d} nanoseconds.")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying and Sorting
#   </div>
# </div>
#
# Now we run the same query, but sort the output. As there are very few records, this doesn't take much longer.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)

# record start time
start = time.time_ns()

x=pd.read_sql_query("select * from test where v>=100 and v<=110 order by v",conn)
print(x)
# record end time
end = time.time_ns()

# print elapsed time in seconds
print(f"Elapsed time using process_time(): {end - start:,d} nanoseconds.")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating the index
#   </div>
# </div>
#
# Now we create the index on column "v". This doesn't produce any output in Python.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)


execSQL(conn,'create index vindex on test(v)')

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Query Again, Using the Index
#   </div>
# </div>
#
# Now we plan to repeat the query. Since that column is indexed, the query will automatically use the index. It should be faster.
#
# Note that the results come out sorted by default.
#
# Here, we don't actually run the query, but rather we ask SQLite to tell us its plan for carrying out the query using EXPLAIN QUERY PLAN. Note that it now plans to use the index.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)


execSQL(conn,'create index vindex on test(v)')
read=pd.read_sql_query('explain query plan select v from test where v>=100 and v<=100',conn)
print(read)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying with the Index
#   </div>
# </div>
#
# Here, we actually run the query using the index.
#
# Note that it is faster.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)


execSQL(conn,'create index vindex on test(v)')
# record start time
start = time.time_ns()

x=pd.read_sql_query("select * from test where v>=100 and v<=110",conn)
print(x)
# record end time
end = time.time_ns()

# print elapsed time in seconds
print(f"Elapsed time using process_time(): {end - start:,d} nanoseconds.")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying and Sorting Using the Index (1)
#   </div>
# </div>
#
# Here, we ask for the query plan for the same query, but with sorted output.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)


execSQL(conn,'create index vindex on test(v)')

read=pd.read_sql_query('explain query plan select v from test where v>=100 and v<=100 order by v',conn)
print(read)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying and Sorting Using the Index (2)
#   </div>
# </div>
#
# Here we run the sorted query. There is no additional time associated with sorting in this case because the index already provides the data in sorted order.

# %%
import sqlite3
import pandas as pd
import os
import random
import time
try:
  os.remove("index_test.db") # remove the database if it is already there
  print("removed earlier copy of index_test.db")
except:
  print("not already there")
# create a connection to a database
conn = sqlite3.connect("index_test.db") # creates the database if it is not already there.
def execSQL(conn,query):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
def allrowsSelect(conn,query):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
# put the SQL to create the tables in a string
execSQL(conn,"drop table if exists test")
createCMD='''
CREATE TABLE if not exists test (
  i integer primary key,
  v integer
)
'''
# execute it
execSQL(conn,createCMD)


query='INSERT INTO test (v) VALUES '
n=100000
for i in range(n):
  query+="("+str(random.randint(1,100000))+")"
  if i<n-1: query+=", "
#print("Our query starts with '",query[:100],"' ...",sep='')
execSQL(conn,query)


execSQL(conn,'create index vindex on test(v)')

# record start time
start = time.time_ns()

x=pd.read_sql_query("select * from test where v>=100 and v<=110 order by v",conn)
print(x)
# record end time
end = time.time_ns()

# print elapsed time in seconds
print(f"Elapsed time using process_time(): {end - start:,d} nanoseconds.")

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 24</div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Indexes in SQLite
#   </div>
# </div>
