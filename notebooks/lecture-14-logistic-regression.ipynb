# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: 1.45em !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: 0.8em !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: 0.74em !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:1.05em;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">14</span>
#     <span style="font-size:1.35em;font-weight:800;line-height:1.15;">Logistic Regression</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">5 content slides &nbsp;&middot;&nbsp; 4 live demos</div>
# </div>

# %% [markdown]
# ## Predicting Probabilities
#
# Suppose we wanted to predict a probability, which must between zero and one.
#
# We could use linear regression. The trouble with doing this, even if the model is trained on data where the target variable is between 0 and 1, it can still predict values outside that interval. One solution to this is to just consider any prediction which is greater than one to be one, and less than zero to be zero.
#
# This is sometimes done, and when it is, it is called the linear probability model. But usually people use another model to predict probabilities, the logistic regression model.

# %% [markdown]
# ## Transforming Probabilities to Log Odds
#
# The idea of logistic regression is based on transforming a probability p to a new value that can range from −∞ to +∞.
#
# We use the following formula to do that:
#
# $$
# \ln(\frac{p}{1-p})
# $$
#
# where ln signifies the natural logarithm (log base 𝑒).
#
# 𝑝1−𝑝 is the odds of an event with probability. For instance, if p is 0.75, 1-p is 0.25 and the odds are 3 (often written as 3 to 1). The odds can be very high (say 999 to 1) or very low (1 to 999) and when we apply the log function to these high or low numbers we get positive or negative numbers.

# %% [markdown]
# ## A Table of Odds and Log Odds
#
# The following code shows the odds and the log odds for probabilities from 10 to the minus 10 up through 0.1, for a probability of 0.5, and for probabilities of 0.9, 0.99, etc. up to 0.999999999. As we can see, the log odds occupies the entire real line in principle, although its growth rate (in magnitude) is slow.

# %%
import math
print(f"{'Probability':15s}{'1-Probability':15s}{'Odds':15s}{'Log Odds':15s}")
for i in range(-10,11,1):
  if i==0:
    odds=1
    print(f"{0.5:.12f} {0.5:.12f} {odds:.12f} {math.log(odds):.3f}")
    continue
  if i<0:
    p=10**i
  else:
    p=1-10**(-i)
  odds=p/(1-p)
  if i<0:
    print(f"{p:.12f} {1-p:.12f} {odds:.12f} {math.log(odds):.3f}")
  else:
    print(f"{p:.12f} {1-p:.12f} {odds:14.2f} {math.log(odds):.3f}")

# %% [markdown]
# ## The Relationship Between Linear and Logistic Regression
#
# Logistic regression is simply linear regression after the target variable, which initially ranges from 0 to 1 (like a probability or a percentage) is transformed to log odds. So we simply have (if we have 𝑚 predictors:
#
# $$
# \ln \frac{p}{1-p} = \beta_0+\beta_1x_1+\beta_2x_2+\cdots+\beta_mx_m
# $$
#
# which transforms to (by exponentiating both sides and re-arranging).
#
# $$
# p = \frac{1}{1+e^{-(\beta_0 + \beta_1 x_1 + \beta_2 x_2 + \cdots + \beta_mx_m )}}
# $$
#
# The function on the right is called the logistic function; the formula shows the logistic function applied to of the linear combination of predictors and betas. The logistic function has a maximum value of one (in the case when the linear combination of predictors becomes very large and positive) and a minimum value of zero (when the linear combination of predictors becomes large in magnitude but negative).
#
# Note in the case of a single predictor, 𝛽<sub>0</sub> becomes 𝛼 and 𝛽<sub>1</sub> simply 𝛽.
#
# Unlike simple linear regression, there is no closed form for estimating the parameters. The parameters (the betas) are usually estimated using a technique called [maximum likelihood estimation](https://online.stat.psu.edu/stat415/lesson/1/1.2) (MLE).

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Loan Default Dataset
#   </div>
# </div>
#
# The following dataset, referred to on [this website](https://www.statology.org/plot-logistic-regression-in-python/), has data on whether or people defaulted on a loan. (The data is originally from the book "An Introduction to Statistical Learning.") The default variable is a zero or a one, one if they defaulted. It is the outcome variable. The data also includes whether or not they are a student, their loan balance, and their income.
#
# There are 10,000 records. Note that the number of defaults is relatively small, 3.33 percent.

# %%
import pandas as pd
data = pd.read_csv("default.csv")
print(data.head(5))
print(data['default'].value_counts())

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Fitting a Logistic Regression to the Loan Default Dataset
#   </div>
# </div>
#
# The code below fits a logistic regression to the default data using the Seaborn graphics library.
#
# The actual data are the black dots and the fit is in red with the characteristic "s" shape.
#
# Further down in the notebook we fit the model with StatsModels to get more information.
#
# We can see that the coefficient on "balance" is positive. This means that as the balance goes up, so does the probability of default.
#
# If we exponentiate the coefficients, we see that every additional dollar of balance increases the odds of default by a factor of 1.005514, although that is just the point estimate.
#
# We then fit the model with scikit-learn to get the predicted values and look at the cases where the predicted value is different than the true value.
#
# We show the "confusion matrix" which summarizes the performance of the model in terms of true negatives, true positives, false negatives, and false positives.
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/6gPsF0H5mZuvlIMn6a3y2mKB.png" alt="" style="max-width:100%;width:565px;height:auto;"></div>

# %%
import pandas as pd 
data = pd.read_csv("default.csv")

import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

#define the predictor variable and the response variable
x = data['balance']
y = data['default']

#plot logistic regression curve
#the actual data is in black and the fit line is in red
sns.regplot(x=x, y=y, data=data, logistic=True, ci=None,
            scatter_kws={'color': 'black'}, line_kws={'color': 'red'});

# %%
import statsmodels.api as sm
X = sm.add_constant(data['balance'], prepend=False)
y=data['default']
log_reg=sm.Logit(y,X).fit()
print(log_reg.summary())

# %%
import numpy as np
np.exp(log_reg.params)

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
y_pred = pd.Series(model.predict(X_test))
y_test = y_test.reset_index(drop=True)
z = pd.concat([y_test, y_pred], axis=1)
z.columns = ['True', 'Prediction']
z[z['True']!=z['Prediction']]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
print(cm)

# %% [markdown]
# ## Concepts in Binary Classification
#
# - True negative: a zero that was correctly predicted as a zero (here, if there was no default, and the model predicted no default)
# - True positive: a one that was correctly predicted as a one (here, if there was a default, and the model predicted a default)
# - False negative: a one that was incorrectly predicted as a zero (here, if there was a default, and the model predicted no default)
# - False positive: a zero that was incorrectly predicted as a one (here, if there was no default, and the model predicted a default)
#
# The "true" ones are when the model got it right, and the "false" ones when it got it wrong.
#
# - True negatives are actually negatives.
# - True positives are actually positives.
# - False negatives are actually positives.
# - False positives are actually negatives.
#
# The goal of any model is to minimize the latter two things, if possible.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Examining Model Performance
#   </div>
# </div>
#
# In the notebook below, we extract the seven false positives. There are the cases where the model predicted default but the true value was no default.
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/XKnfCnughgeIU2hQxAAJoem7.png" alt="" style="max-width:100%;width:470px;height:auto;"></div>
#
# ### Accuracy, Precision and Recall
#
# #### Accuracy
#
# Three of the metrics of model performance are accuracy, precision, and recall.
#
# The first metric, accuracy, is the percent of the time that the model was correct overall.
#
# Another way to put this is that is the sum of the true negatives and the true positives divided by the total size of the dataset.
#
# Since it is wrong in 63 cases out of the 2500 in the test set, that comes out to 97.4% accuracy.
#
# What would the accuracy be if the model always picked no default (zero)? Remember only three percent of the cases are defaults.
#
# #### Precision
#
# Precision is defined with respect to the total number of times the model predicted a positive result. It is the share of those predictions that are correct.
#
# Another way to say this is that it is the true positives divided by the sum of the true positives and false positives. Ideally, there would be no false positives.
#
# So here it is the share of correct default predictions divided by all default predictions. That is 22 out of 29, or 75.9 percent.
#
# #### Recall
#
# Recall is defined as the share of the true positive values detected by the model, that is the true positives divided by the sum of the true positives and the false negatives. This is the metric on which the model does the worst. Recall is also called sensitivity, hit rate, or true positive rate (TPR)
#
# There are 78 actual defaults and the model detected 22 of these, missing 56. That is 28.2% recall
#
# ### The Threshold
#
# By default, when logistic regression is used for binary classification, probabilities above 0.5 are considered ones and below 0.5, zeros. Thus 0.5 is called the threshold.
#
# What would happen to the number of positives detected when you lower the threshold? How about false positives? How about false negatives?
#
# ### The Receiver Operating Characteristic (ROC) Curve
#
# The Receiver Operating Characteristic (ROC) curve shows the tradeoffs when you raise or lower the threshold.
#
# It was originally developed in the context of radar in World War II. Allied radar receivers were detecting Japanese aircraft.
#
# If you lowered their detection threshold a lot, you would detect more Japanese aircraft, but you would have more false positives, which would mean you would try to attack more planes that weren't Japanese.
#
# However, if you raised it, you would have too many false negatives, that is, you would miss some Japanese planes.
#
# The ROC curve for this default detection model is shown in the notebook below.
#
# On the left of the plot, it shows that if we raise the threshold sufficiently, our chance of false alarm can be lowered to zero, but we will only detect about 20 percent of the true positives.
#
# As we move along the blue curve, the threshold is lowered. This increases the true positive rate (recall) but at the expense of the false positive rate. We can achieve 100 percent recall, but we will need to tolerate 30-40 percent false positives. That is, 30-40 percent of the true negatives will be incorrectly classified as positive.
#
# The area under the curve (AUC) is a measure of the performance of the classifier. Here it is 0.96.

# %%
import pandas as pd 
data = pd.read_csv("default.csv")

import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

#define the predictor variable and the response variable
x = data['balance']
y = data['default']

# %%
from sklearn import metrics
import statsmodels.api as sm
X = sm.add_constant(data['balance'], prepend=False)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)
model = LogisticRegression()
model.fit(X_train, y_train)

# %%
y_pred = pd.Series(model.predict(X_test))
y_test = y_test.reset_index(drop=True)
z = pd.concat([y_test, y_pred], axis=1)
z.columns = ['True', 'Prediction']
z[(z['Prediction']==1) & (z['True']==0)]

# %%
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))

# %%
z[z['Prediction']==1]['True'].value_counts()

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification
probs = model.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

import matplotlib.pyplot as plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
#plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate (Recall)')
plt.xlabel('False Positive Rate (Chance of False Alarm)')
plt.show()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Graduate School Admission Data
#   </div>
# </div>
#
# Let's play with some graduate admission data. There is an outcome variable "admit" which we want to predict in terms of the other three variables, which are their GRE score, their undergraduate GPA, and rank, which is a measure of the selectivity of their undergraduate school.
#
# The data is in Stata format, but pandas can read it; it can read quite a few different formats.
#
# We convert the rank variable, which is categorical, into a set of dummy variables so we can use it in the model. It is usually not a good idea to use a categorical variable directly in a model.
#
# We then examine the data with the pandas describe method.
#
# Out of 400 applicants, 273 students were not admitted and 127 were. That is a 31.75% admission rate.
#
# Using StatsModels, we run a logistic regression that predicts admission.
#
# We then create a 75/25 train/test split. Three quarters of the data is used for training and 25 percent for testing. We fit the data using the training set and then look at the confusion matrix for the test set.
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/BULdpG9rLo1jD3wP7Kbk9JVA.png" alt="" style="max-width:100%;width:565px;height:auto;"></div>
#
# We then print out the accuracy, precision, and recall.

# %%
import pandas as pd 
admission_data=pd.read_stata("binary.dta")
admission_data

# %%
onehot=pd.get_dummies(admission_data['rank'],prefix="rank", dtype=int)
admission_data=admission_data.drop('rank',axis=1)
onehot=onehot.drop('rank_1.0',axis=1)
admission_data=admission_data.join(onehot)
admission_data

# %%
admission_data.describe()

# %%
admission_data['admit'].value_counts()

# %%
import statsmodels.api as sm
X = sm.add_constant(admission_data[['gre','gpa','rank_2.0','rank_3.0','rank_4.0']], prepend=False)
y=admission_data['admit']
log_reg=sm.Logit(y,X).fit()
print(log_reg.summary())

# %%
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=123)

# %%
model = LogisticRegression(max_iter=1000, penalty=None)
model.fit(X_train, y_train)
model.coef_

# %%
y_pred = pd.Series(model.predict(X_test))
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test, y_pred)
print(cm)

# %%
from sklearn import metrics
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 14</div>
#   <div style="font-size:1.15em;font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Logistic Regression
#   </div>
# </div>
