# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
#
#   /* Slide titles, px for the same reason. Every heading and every card in a
#      deck sits inside `.jp-RenderedHTMLCommon`, which JupyterLab sizes at 14px
#      -- NOT the 26px this theme puts on the slide. So the `1.45em` this rule
#      used to carry rendered at 20.3px, and the lecture title's `1.35em` at
#      18.9px, i.e. the title card came out SMALLER than the slide titles under
#      it and both sat within a couple of px of the 18px code. */
#   --dma-title-size: 22px;
#
#   /* Body prose. This is JupyterLab's own variable rather than a `--dma-` one:
#      `.jp-RenderedHTMLCommon` sizes itself from it, and everything inside a
#      rendered markdown cell inherits from there -- paragraphs, list items,
#      table cells, blockquotes. Setting it here lifts all of them at once, and
#      scoped to `.reveal` it changes the deck only, never the notebook editor.
#      It also gives the theme's remaining `em` values something sensible to
#      anchor to: inline code at `0.92em` and the small-caps card labels scale
#      with the prose instead of against JupyterLab's 14px default. The sizes
#      that must not move with it -- slide titles, code, output -- are all in px
#      above. */
#   --jp-content-font-size1: 17px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: var(--dma-title-size) !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:18px;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">7</span>
#     <span style="font-size:24px;font-weight:800;line-height:1.15;">Python Named Tuples and Classes</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">14 content slides &nbsp;&middot;&nbsp; 2 in-class exercises</div>
# </div>

# %% [markdown]
# ## Storing a point in two dimensions
#
# We could store a point as two separate floats:

# %%
x,y=4.1,5.2
print(x,y)

# %% [markdown]
# Or as a two element list or two element tuple:

# %%
p=[4.1,5.2]
print(p)
p=(4.1,5.2)
print(p)

# %% [markdown]
# Or as a dictionary:

# %%
p={'x':4.1, 'y':5.2}
print(p['x'],p['y'])

# %% [markdown]
# ## Named Tuples
#
# Another way to create a point is using a [named tuple](https://docs.python.org/3/library/collections.html#collections.namedtuple) from Python's collections module which allows you to access the elements of the tuple by index or by name (the latter as an attribute). Each position in the tuple gets a name.
#
# To define a named tuple, you call "namedtuple" with the name of the type of object and the names of the fields in the object (as a list), as follows.
#
# Here we define a type called "Point". We can do this with either named arguments or positional arguments.

# %%
from collections import namedtuple
Point=namedtuple('Point',['x','y'])

# create using named (keyword) arguments 
p=Point(y=5.2,x=4.1)
print(p.x)
print(p.y)

# %% [markdown]
# In the following, we create a Point with positional arguments and access them with indices.

# %%
from collections import namedtuple
Point=namedtuple('Point',['x','y'])
q=Point(7.1,-4.3)
print(q)

# three ways to access x
print(q[0])
print(q.x)
print(q[-2])

# three ways to access y
print(q[1])
print(q.y)
print(q[-1])

# %% [markdown]
# ## Unpacking Named Tuples
#
# We can unpack the named tuple like an ordinary tuple.

# %%
from collections import namedtuple
Point=namedtuple('Point',['x','y'])
q=Point(7.1,-4.3)

x, y = (1.1, 2.3) # ordinary tuple
print(x, y)
x, y = q # named tuple
print(x, y)

# %% [markdown]
# ## Named Tuples are Immutable
#
# Like ordinary tuples, named tuples are immutable.

# %%
from collections import namedtuple
Point=namedtuple('Point',['x','y'])
q=Point(7.1,-4.3)
t=(1.1,3.5)
try:
  t[0]=1.2
except:
  print("Can't reassign elements in an ordinary tuple.")
try:
  q[0]=1.5
except:
  print("Can't reassign elements in a named tuple.")
l=[1.1,3.5]
l[0]=1.2 # not a problem with a list
print(l)

# %% [markdown]
# ## Named Tuple Type
#
# What are the types of these objects?

# %%
from collections import namedtuple
Point=namedtuple('Point',['x','y'])
q=Point(7.1,-4.3)
print(type(Point)) # Point is a type of object
print(type(q)) # this is a instance of the type

BabyCarriage=namedtuple('Point',['x','y']) # name of the type doesn't matter
r=BabyCarriage(8.3,7.1)
print(type(r)) # the type is still named Point
print(r)

# %% [markdown]
# Named tuples can be useful, but they are limited. They are immutable, which is limiting in many cases, and they have only the methods associated with tuples, as well as the ability to address elements by name.

# %% [markdown]
# ## Classes
#
# Classes are much more powerful and flexible (than limited objects like named tuples).
#
# - They are a way to define a new type of objects and instantiate them
# - They can define methods, which are class-specific functions
# - They can represent arbitrary data structures
# - Like in other object-oriented languages such as Java, they support inheritance, encapsulation, and polymorphism

# %% [markdown]
# ## Python Programmer-Defined Objects and Classes
#
# #### Terminology
#
# - A class defines a type of object
# - An object is an instance of a class
# - When defining a class, we define attributes and methods of that class
# - An attribute is a variable associated with a class and its objects
# - A method is a function associated with a class and its objects
#
# #### We can define our own classes and then create objects using them.

# %% [markdown]
# ## Syntax of Programmer-Defined Classes
#
# - "Class" keyword defines a class giving the class name
# - Methods are defined as functions indented under the class
# - "Self" refers to the object itself
# - All methods (except for static methods) refer to self and optionally some other arguments
# - Special "dunder" methods begin and end with double underscore

# %% [markdown]
# ## Class Methods
#
# Methods that start and end with double underscores have special meaning in Python. They may specify the "constructor" function, provide a mechanism for operator "overloading" (like using +, \*, etc.), and carry out string conversion.
#
# - The \_\_init\_\_ method is used to create an object
# - The \_\_str\_\_ method is used to tell the print function how to print an object
# - The \_\_repr\_\_ method is used to create a string representation for use in debugging (for example), for instance when evaluating in the interactive Python shell.
# - The \_\_eq\_\_ tells the == operator when two objects are equal
# - Methods are called with dot notation
# - Objects are created with the class name and the arguments to \_\_init\_\_
#
# There are [many other magic or dunder methods](https://rszalski.github.io/magicmethods/) like \_\_mul\_\_  and \_\_or\_\_ .

# %% [markdown]
# ## A Dog Class
#
# The following is a class for dogs, that stores four attributes per dog. The age of a dog can't exceed 29.

# %%
# define a class
class Dog:
  def __init__(self,name,weight,age,got_rabies_shot):
    self.name=name
    self.weight=weight
    if age<=29: # validate
      self.age=age
    else:
      raise ValueError("That is too old.")
    self.got_rabies_shot=got_rabies_shot
  def __str__(self):
    s=self.name+" is a dog that weighs "
    s+=str(self.weight)+" pounds and is "
    s+=str(self.age)+" years old;"
    if self.got_rabies_shot:
      s+=" vaccinated for Rabies."
    else:
      s+=" not vaccinated for Rabies."
    return s

# create an instance
dog1=Dog("Fido",25,1,False)
# print out the attributes
print(dog1.name)
print(dog1.weight)
print(dog1.age)
print(dog1.got_rabies_shot)

# try to create a dog that is too old
try:
  d=Dog("Spike",50,40,True)
except ValueError as e:
  print(e)
try:
  print(d)
except NameError as e:
  print(e)

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Add a method to the dog class
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713095" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       First exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713095</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## A Point Class
#
# The following is a point class with two methods, ManhattanDistance and EuclideanDistance.

# %%
import math
class Point: # class definition, starts with keyword "class"
    '''Creates a point on a coordinate plane with values x and y.'''

    def __init__(self, x, y): # method called when an object is created
        '''Defines x and y variables'''
        self.x = x
        self.y = y

    def __str__(self): # method called when an object is printed
        return "Point(%s,%s)"%(self.x, self.y)
    def ManhattanDistance(self,other):
        return abs(self.x-other.x)+abs(self.y-other.y)
    import math
    def EuclideanDistance(self,other):
        return math.sqrt((self.x-other.x)**2+(self.y-other.y)**2)

# create two points
p=Point(0,0)
q=Point(3,4)
print(p.x) # 0
print(p.y) # 0
print(p)
print(q)
print(p.ManhattanDistance(q))
print(p.EuclideanDistance(q))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     A Circle Class
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713095" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Second exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713095</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## A Poker Simulation Using Python Classes
#
# Following is a class that deals a random card from a deck and a class that deals a hand of cards from that deck. We then estimate the frequency of five-card poker flushes by simulating a lot of draws from the deck. The actual frequency considering all hands is 0.1965% which is a about two flushes per thousand hands.

# %%
import random

class RandomCard:
    '''
    Class that creates objects that are random cards drawn from a deck
    with replacement
    '''
    def __init__(self):
        '''draw a card by pulling a random suit and value in that suit'''
        suits = ("Hearts","Diamonds","Spades","Clubs")
        values = ("Ace","2","3","4","5","6","7","8","9","10","Jack","Queen","King")
        self.suit = random.choice(suits)
        self.value = random.choice(values)

    def __str__(self):
        '''printing method'''
        return self.value+" of "+self.suit

    def same_suit(self,other):
        '''checks if two cards have the same suit'''
        return self.suit == other.suit

    def __eq__(self,other):
        '''checks if two cards are the same'''
        return (self.suit==other.suit) and (self.value==other.value)

class Hand:
    '''deal a hand of n cards'''
    def __init__(self,n):
        '''pull n cards at random'''
        self.cards = []
        i = 1
        while i <= n:
            card = RandomCard()
            # make sure you don't add the same card twice
            if card not in self.cards:
                self.cards.append(card)
                i += 1

    def __str__(self):
        '''print a hand; relies on str method from random_card class'''
        s = "("
        for i in range(len(self.cards)):
            s += self.cards[i].__str__()
            if i < len(self.cards)-1:
                s += ', '
            else:
                s += ")"
        return s
    def flush(self):
        check = True
        for card in self.cards[1:]:
            if not(RandomCard.same_suit(self.cards[0],card)):
                check = False
        return check

print(Hand(5)) # print a sample hand

# count the number of flushes in 100,000 hands
num_flush = 0
for i in range(100000):
    h = Hand(5)
    if h.flush(): num_flush += 1

print("Frequency of flushes:",num_flush / 100000)

# %% [markdown]
# ## A Student Class
#
# The following class represents a student at NYU with their netid and first and last names.

# %%
class Student:
    def __init__(self, netid, first, last):
        self.netid = netid
        self.first = first
        self.last = last

    def __str__(self):
        # string representation (human readable)
        return f"{self.first} {self.last}"

    def __repr__(self):
        # string represenation of the actual object (for debugging purposes)
        return f"Student(netid={self.netid},first={self.first},last={self.last})"

    def __eq__(self, other):
        return self.netid == other.netid

# __init__ called
s = Student('cb2312', 'Charlie', 'Brown')
# __str__ called
print(s)
# __repr__ called
print(repr(s))
# defining __eq__ such that same netids mean same student:
clone = Student('cb2312', 'Charles', 'Brown')
print(s == clone) # True

# %% [markdown]
# ## A Fraction Class
#
# The following class represents a fraction of two integers.
#
# It includes a method called gcf which is a static method, which means it is called on the class rather than an instance of the class.
#
# It also implements \_\_add\_\_ and \_\_getitem\_\_ magic methods. The \_\_add\_\_ method overloads the "+" operator and \_\_getitem\_\_ implements indexing.

# %%
class Fraction:

    def __init__(self, n, d):
        self.n = n
        self.d = d

    # this means that this method can be called without an instance
    # and consequently, no self is needed
    # instead, you call it using the actual class name
    # Fraction.gcf(a,b)
    # note the use of a decorator to create this
    @staticmethod
    def gcf(a, b):
        # go through every possible factor
        # check if it divides evenly into both
        # return the largest one
        cur_gcf = 1
        for factor in range(1, min(a,b)+1):
            if a % factor == 0 and b % factor == 0:
                cur_gcf = factor
        return cur_gcf

    def reduce(self):
        gcf = Fraction.gcf(self.n, self.d)
        return Fraction(self.n // gcf, self.d // gcf)

    def __str__(self):
        return "{}/{}".format(self.n, self.d)

    def __repr__(self):
        # we can call methods that are already defined
        return self.__str__()

    def add(self, other):
        new_n = (self.n * other.d) + (other.n * self.d)
        new_d = self.d * other.d
        return Fraction(new_n, new_d)

    def __add__(self, other):
        return self.add(other)

    # allow indexing! Indexing with 0 gives back the numerator
    # while indexing with 1 gives back the denominator...
    # any other index will result in an IndexError
    def __getitem__(self, i):
        if i == 0:
            return self.n
        elif i == 1:
            return self.d
        else:
            raise IndexError('Index must be 0 or 1')
    def __eq__(self,other):
       return (self.reduce().n==other.reduce().n) and (self.reduce().d==other.reduce().d)

# create and print three fractions
a = Fraction(1, 2)
b = Fraction(6, 8)
c = Fraction(1, 3)
print(f'a:{a}, b:{b}, c:{c}')

# you can index into them:
print(b[0], b[1])
# or use the attributes
print(b.n, b.d)

try:
    print(a[987]) # must be 0 or 1
except IndexError as e:
    print(type(e), e)
print(a.add(c)) # a is 1/2 and c is 1/3 so this gives 5/6
print(a+c) # again 5/6
print(a==Fraction(3,6)) # True because reduces first
print(Fraction(4,8).reduce()) # prints 1/2

# static method, called on class rather than instance
print(Fraction.gcf(9,12)) # 3
# can call on instance but is not recommended because it 
# doesn't make sense (doesn't have to do with any particular instance)
print(a.gcf(9,12)) # 3

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 7</div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Python Named Tuples and Classes
#   </div>
# </div>
