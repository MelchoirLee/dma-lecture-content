# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: 1.45em !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:1.05em;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">18</span>
#     <span style="font-size:1.35em;font-weight:800;line-height:1.15;">Pandas Part 3</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">20 live demos &nbsp;&middot;&nbsp; 2 in-class exercises</div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     City Rainfall Data
#   </div>
# </div>
#
# Let's load some rainfall data into a DataFrame, for four cities for four months.

# %%
# rain data
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
print(rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Total Rainfall by Month Using &quot;apply&quot; and &quot;lambda&quot;
#   </div>
# </div>
#
# Apply allows a function to be called on a ow or column.
#
# d.apply(fn,axis=a)
#
# - fn is the function name
# - axis may be 0 for rows (default) or 1 for columns
#
# In the code below, we use apply to find the total rainfall per month across all four cities. The result, since it is one dimensional, is a series.
#
# Since axis is 0, it sums across the rows for each column.

# %%
# rain data
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
print(rain)
print()
total_rain_by_month=rain.apply(lambda x: sum(x)) # if axis is omitted, it is set to zero (rows)
print(total_rain_by_month)
print(type(total_rain_by_month))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Total Rainfall by Month: Another Method
#   </div>
# </div>
#
# We can achieve the same results that we got in the last slide by just applying NumPy's sum function rather than a lambda function.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
print(rain)
# can use any of numpy's functions
rain.apply(np.sum)
print(rain.apply(np.sum))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Calculating Rainfall Totals by City
#   </div>
# </div>
#
# If we change the axis to 1 (columns), we get total rainfall by city, rather than total rainfall by month, as in the code below.
#
# Since axis is 1, it sums across the columns for each row.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()

total_rain=rain.apply(lambda x: sum(x), axis=1)

print(total_rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Computing Monthly Average Rainfall
#   </div>
# </div>
#
# If we use the mean function instead of sum, we get the average rainfall per month.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()

Average_rain=rain.apply(np.mean)

print(Average_rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Computing Average Rainfall for Each City
#   </div>
# </div>
#
# If we apply the mean function with axis=1, we get the average rainfall for each city, as in the code below.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()

Average_rain=rain.apply(np.mean,axis=1)

print(Average_rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Calculating Monthly Rainfall Variability
#   </div>
# </div>
#
# We can use the standard deviation function to find the standard deviation for each month's observations, as shown below.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()

std=rain.apply(np.std)

print(std)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Rainfall Standard Deviation by City
#   </div>
# </div>
#
# Changing the axis to one gives us the standard deviation for each city's observations.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()

std=rain.apply(np.std, axis=1)

print(std)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Rainfall Data Summary Statistics
#   </div>
# </div>
#
# By using the pandas describe method, we can quickly obtain a statistical summary that includes count, mean, standard deviation, minimum, maximum, and the quartiles for the dataset, thus offering a comprehensive overview of the rainfall patterns.
#
# It gives the data by column (month).

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain.describe())

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Monthly Rainfall Descriptive Statistics by City
#   </div>
# </div>
#
# By transposing the DataFrame with .T and then applying the describe method, we get descriptive statistics for each city's observations (four months per city).

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()
print(rain.T)
print()
print(rain.T.describe())

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Maximum Rainfall by Month
#   </div>
# </div>
#
# By using the NumPy max, function, we can find the maximum rainfall by month.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print()
maxrain=rain.apply(np.max)
print(maxrain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Maximum Rainfall by Month using lambda
#   </div>
# </div>
#
# The code below does the same thing as the previous slide, but uses lambda and a pandas method instead of NumPy.

# %%
# rain data
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
# use the pandas max instead of numpy
print(rain)
print()
maxrain=rain.apply(lambda x: x.max())
print(maxrain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Minimum Monthly Rainfall by City
#   </div>
# </div>
#
# This code shows the minimum monthly rainfall by city and in which month it occurred.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

print(rain)
print(rain.min(axis=1))
print(rain.idxmin(axis=1))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise 1
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713056" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       First exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713056</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Map
#   </div>
# </div>
#
# The map method works on every element in a Series or DataFrame. In the example below, we add "s" to some words.

# %%
import numpy as np
import pandas as pd
animals=['ant','cat','bat']
animal=pd.Series(animals).map(lambda word: word + "s")
print(animal)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Calculating Factorials in a DataFrame
#   </div>
# </div>
#
# The code below defines  a function to compute the factorial of a number and applies this function to a 3x3 DataFrame generated from a sequence of numbers.

# %%
import numpy as np
import pandas as pd

# apply factorial to the numbers in a 3x3 DataFrame containing the numbers from 0 to 8
def factorial(n): return 1 if n==0 else n*factorial(n-1)
nums=pd.DataFrame(np.arange(9).reshape(3,3))
print(nums)

nums=nums.map(factorial)
print(nums)

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise 2
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713056" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Second exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713056</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Rounding the Rainfall Data
#   </div>
# </div>
#
# In the code below, we round every number in the rainfall data.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
# built in method that applies to all elements
rain=rain.round(1)
print(rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Incrementing Rainfall Measurements
#   </div>
# </div>
#
# Here we add 10 to every rainfall measurement. It may not make sense to do this, but we can ...

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])
# this doesn't make much sense in this context,
#but maybe they systematically undermeasured rainfall by 10 inches
rain=rain.add(10)
print(rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Adding and Rounding
#   </div>
# </div>
#
# In the example below, we add 10, and then round to the nearest integer.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

# can chain these
rain=rain.add(10).round(0)
print(rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Rainfall Conversion from Inches to Centimeters
#   </div>
# </div>
#
# Here, we use a lambda function to convert the rainfall in inches to centimeters using map.

# %%
# rain data
import numpy as np
import pandas as pd
rain = pd.DataFrame([[3.50, 4.53, 4.13, 3.98],
                     [7.91, 5.98, 6.10, 5.12],
                     [3.94, 5.28, 3.90, 4.49],
                     [1.42, 0.63, 0.75, 1.65]],
    index=['New York', 'New Orleans', 'Atlanta', 'Seattle'],
    columns=['Jun', 'Jul', 'Aug', 'Sept'])

# convert inches to cm in rainfall data
rain=rain.map(lambda x: 2.54*x)
print(rain)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Formatting Financial Data in a Pandas DataFrame
#   </div>
# </div>
#
# Here we load the company data again, and then reformat the revenue column by removing the dollar sign and converting the string to a float.
#
# Note we couldn't run describe on that column without turning it into a number.

# %%
import pandas as pd
d = [["$229.2", 2017, 123000, "$1100", "Cupertino, US"],
     ["$211.9", 2017, 320671, "$284", "Suwon, South Korea"],
     ["$177.8", 2017, 566000, "$985",  "Seattle, US"],
     ["$154.7", 2017, 1300000, "$66", "New Taipei City, Taiwan"],
     ["$110.8", 2017, 80110, "$834", "Mountain View, US"]]

comps = ["apple", "samsung", "amazon", "foxconn", "alphabet"]
cols = ["revenue", "fy", "employees", "mcap", "location"]

c = pd.DataFrame(d, index=comps, columns=cols)
# that didn't reset it: the following will
c['revenue']=c['revenue'].map(lambda x: float(x[1:]))
print(c)
print(c['revenue'].describe())

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 18</div>
#   <div style="font-size:1.15em;font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Pandas Part 3
#   </div>
# </div>
