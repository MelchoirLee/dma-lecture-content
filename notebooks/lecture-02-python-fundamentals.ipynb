# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: 1.45em !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: 0.8em !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: 0.74em !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:1.05em;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">2</span>
#     <span style="font-size:1.35em;font-weight:800;line-height:1.15;">Python Fundamentals</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">14 content slides &nbsp;&middot;&nbsp; 1 in-class exercises</div>
# </div>

# %% [markdown]
# ## A Neat "Pythonic" Sorting Program
#
# This program for Quicksort is borrowed from [this tutorial](https://cs231n.github.io/python-numpy-tutorial/).
#
# I think it nicely illustrates the power of Python.
#
# How do you think it works?

# %%
def quicksort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quicksort(left) + middle + quicksort(right)

print(quicksort([3,6,8,10,1,2,1]))

# %% [markdown]
# ## Assignment and Operators
#
# Python variable names can have alphanumeric characters and the underscore; they must begin with an alphabetic character or an underscore.
#
# The following code illustrates the assignment operator and the basic arithmetic operators including integer division and modulo.
#
# It also illustrates f-strings in Python, which allow you to interpolate any expression into a string by enclosing it in braces. You do this by prefixing the string with the letter "f".

# %%
x=20
y=9
print(f"The value of x is {x} and the value of y is {y}.")
print(f"Their sum is {x+y}.") # 29
print(f"x minus y is {x-y}.") # 11
print(f"x times y is {x*y}.") # 180
print(f"x squared is {x**2}.") # 400
print(f"x divided by y is {x/y}.") # 2.2222222222222223
print(f"x divided by y (using integer division) is {x//y}.") # 2
print(f"x modulo y is {x%y}") # 1

# %% [markdown]
# ## Augmented Assignment Operators
#
# Python also has augmented assignment which combine an operation like addition or subtraction with assignment. These are best illustrated by example.

# %%
x=10
print(f"Initally, x is {x}.")
x+=5 # same as x=x+5
print(f"After adding 5 to x, x is now {x}.")
x-=2 # same as x=x-2
print(f"After subtracting 2 from x, x is now {x}.")
x*=2
print(f"After doubling 2, x is now {x}.")
x%=6 # same as x=x%6
print(f"After setting x to the remainder when dividing x by 6, x is now {x}.")
x**=3 # same as x=x**3
print(f"After cubing x, x is now {x}.")
x//=3 # same as x=x//3
print(f"After dividing x by 3 (integer division), x is now {x}.")
x/=(0.2) # same as x=x/(0.2)
print(f"After dividing x by 0.2, x is now {x}.")

# %% [markdown]
# ## Tuple Assignment
#
# In Python, you can assign to a tuple, which is Python sequence type where the individual items are separated by commas, as follows:

# %%
x, y = 1, 2 # sets x to 1 and y to 2
print(x, y)
# reverse them
y, x = x, y # very "Pythonic"
print(x,y)

# %% [markdown]
# ## Indentation in Python
#
# Python uses indentation to create code blocks, as in the following definition of a prime testing function.
#
# The use of whitespace/indentation for code blocks makes Python code very readable and is part of the reason for Python's popularity. The downside is that it is very easy to make indentation mistakes.

# %%
def isPrime(x): # indentation level 0
    # check divistors up to the square root of x
    if x<2: return False # indentation level 1
    for i in range(2,int(x**0.5)+1): # indentation level 1
        if x%i==0: # indentation level 2
            return False # indentation level 3
    return True # indentation level 1
print(isPrime(13)) # True
print(isPrime(14)) # False

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Finding Primes
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.7em 0.9em;font-size:0.72em;color:#6b6478;">
#     <b style="color:#b26a00;">Exercise link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">
#       &lt;paste URL here&gt;
#     </span>
#   </div>
# </div>

# %% [markdown]
# ## Basic Types in Python
#
# - Integer: int
# - Floating point: float
# - String: str
# - Boolean: bool
#
# There are also more complex types, like lists, tuples, sets and dictionaries, that we will cover later. Python also allows for arbitrary user-defined types, and many modules, like pandas and NumPy, define their own types.

# %% [markdown]
# ## The Boolean Type
#
# Variables of a boolean type can take on two values, True or False. They can be set as the result of a comparison and can be used as the condition in "if" or "while" statements. Here is an example that uses a temperature.
#
# They can be combined using the "and," "or," and "not" logical operators.

# %%
temp=31
freezing=(temp<32)
print(freezing) # True
boiling=(temp>212)
print(boiling) # False
print(type(boiling))
print(boiling or freezing) # True
print(boiling and freezing) # False
print(not(boiling)) # True

# %% [markdown]
# ## Python: Strongly and Dynamically Typed
#
# Strong typing in this context means that there is no automatic conversion of objects to the necessary type. In the following example, Python could have chosen to convert the integer 4 to a string and concatenate it to "hello" to get the string "4hello", but that is not the policy, and therefore it generates a run-time error which is trapped by the "try ... except" syntax. (The "+" operator in the context of strings signifies concatenation.)

# %%
try:
  print(4+"hello")
except:
  print("Error generated; can't add different types")

# %% [markdown]
# However, it has no problem combining like objects, selecting an appropriate operation based on the types of objects involved:

# %%
print(4+6) # addition
print("hello"+" world") # string concatenation
print([1,2,3]+["hello", "world"]) # list concatenation

# %% [markdown]
# ## Dynamic Typing
#
# Python allows you to easily change the type of a variable without any type declarations. It deduces the type based on the context.
#
# In the following example, the variable x is set first to an integer, and then to a string. This works because Python variables are pointers to objects in memory.

# %%
# easily change the type of a variable
# x is initially set to a string
x="hello"
print(x)
print(type(x))
# x is now set to an integer
x=5
print(x)
print(type(x))

# %% [markdown]
# ## The "Input" Function and the "If" Statement
#
# Python collects input with the "input" function, and makes decisions with the "if" statement which has optional "elif" and "else" components.
#
# The following collects a temperature from the user and classifies it.

# %%
temp=float(input("Enter a temperature in Fahrenheit: "))
if temp<32:
  print("Below the freezing point of water")
elif temp>212:
  print("Above the boiling point of water")
else:
  print("Between boiling and freezing")

# %% [markdown]
# ## Loops: "For" Loops
#
# Python has "for" loops when a fixed number of repetitions are involved.

# %%
# add the numbers from 1 to 10 using a for loop
total=0
for i in range(1,11): # the range function here runs from 1 to 10 (11 is omitted)
  total+=i
print(total)

# %% [markdown]
# You can also loop through a list or a tuple:

# %%
for item in ("apple","pear","peach"):
    print(item)

# %% [markdown]
# ## Loops: "While" Loops
#
# "While" loops are condition-controlled. Here is a while loop that adds up the numbers from 1 to 10.

# %%
# do the same using a while loop
i=1
total=0
while i<=10:
  total+=i
  i+=1
print(total)

# %% [markdown]
# ## Python Modules
#
# Python can be extended via modules which are made available with the "import' statement. There are many modules; three of which we use later are NumPy, pandas, and sqlite3.
#
# Here we illustrate the use of the random and math modules:

# %%
import random
import math
print(math.pi) # the math module contains the approximate value of pi
# generate a list of the numbers from 1 to 6
die=list(range(1,7))
print(die)
# pick a random one of them
print(random.choice(die))

# %% [markdown]
# ## Strings
#
# Strings are sequences of characters. There are various methods available on strings, for instance upper(), lower(), title() and capitalize(). (Methods are functions that are specific to a particular class of objects.)
#
# - upper: converts the string to all upper case
# - lower: converts the string to all lower case
# - title: capitalizes each word in the string
# - capitalize: capitalizes the first latter in the string
#
# For example:

# %%
phrase='the rain in Spain is mainly on the plane'
print("The original string is:", phrase)
print("In upper case:", phrase.upper())
print("In lower case:", phrase.lower())
print("In title case:", phrase.title())
print("Capitalized:",phrase.capitalize())

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 2</div>
#   <div style="font-size:1.15em;font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Python Fundamentals
#   </div>
# </div>
