# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: 1.45em !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: 0.8em !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: 0.74em !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:1.05em;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">32</span>
#     <span style="font-size:1.35em;font-weight:800;line-height:1.15;">Introduction to MongoDB</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">15 content slides &nbsp;&middot;&nbsp; 1 live demos &nbsp;&middot;&nbsp; 3 in-class exercises</div>
# </div>

# %% [markdown]
# ## MongoDB
#
# MongoDB is an example of a document database. Rather than storing data in a collection of tables as is done in a relational database, MongoDB focuses on storing and querying documents in a format based on JSON.

# %% [markdown]
# ## Relational Databases
#
# #### Relational Databases
#
# - relational databases are typically pretty rigid:
#   - highly structured
#   - you have to define the columns and the types of columns before inserting rows
#   - have a lot of features for maintaining data integrity (such user defined data constraints, foreign keys, etc.)
# - Many relational databases guarantee that transactions (or changes in the database) are reliable
# - Relational databases often offer ACID compliance - Atomicity, Consistency, Isolation, Durability

# %% [markdown]
# ## NoSQL Databases
#
# Let's contrast relational databases with NoSQL databases (that is, non SQL, non relational, or even Not Only SQL.)
#
# So, some common ideas (not necessarily correct) about NoSQL Databases, such as key-value and document stores, are that they are:
#
# - sometimes more simple in design and architecture
# - are less rigid / more flexible than relational databases
# - may be easier to scale "horizontally"
# - data is not necessarily normalized
# - the underlying structures aren't limited to tables (key-value, document, graph, etc.)

# %% [markdown]
# ## Compromises Made by NoSQL Databases
#
# NoSQL databases sound good: why didn't we start using them in the first place?
#
# Some compromises that a NoSQL database may have to make:
#
# - not usually ACID compliant (though MongoDB has had some level of ACID compliance since ~2018/ version 4)
# - simple data structures and architecture moves constraints and referential integrity to application layer
# - lack of standard (or at least mostly standard) language like SQL
# - some NoSQL systems even exhibit lost writes or data loss (because not ACID compliant)
# - Again, these are very broad generalizations (some NoSQL databases are ACID compliant)

# %% [markdown]
# ## Document Stores
#
# In document stores, data is organized (as the name implies) as semi-structured documents
#
# - think JSON (other formats too: XML, YAML, etc.)
# - or… a richer key-value store (there's meta data within the document… the keys are usually meaningful)
# - typically, no schema is required (that is, data types of values are inferred from values)
# - typically, semi structured (documents, property names, etc… do not have to be pre-defined with schemas)
# - some document stores are are known for high availability and scaling through replication / redundancy and sharding (separating large databases into smaller ones)
#
# They are good for applications where flexible data storage or constantly changing data storage is required.

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: ACID
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.7em 0.9em;font-size:0.72em;color:#6b6478;">
#     <b style="color:#b26a00;">Exercise link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">
#       &lt;paste URL here&gt;
#     </span>
#   </div>
# </div>

# %% [markdown]
# ## MongoDB
#
# MongoDB is a Nosql database. Specifically, it's a document store:
#
# - a single record in Mongo is a document
# - a document is a bunch of key value pairs…
# - documents are similar to JSON / JavaScript objects or Python dictionaries
# - it's actually BSON, a binary version of JSON
# - for convenience, we can say that MongoDB uses JSON document to store records

# %% [markdown]
# ## JSON
#
# JSON (JavaScript Object Notation) is a data interchange format / file format that is composed of key value pairs.
#
# A single JSON document consists of:
#
# - curly braces
# - keys and values joined by :
# - key/value pairs separated by commas
# - all keys must be double quoted
# - values can be numbers, strings, arrays or other JSON documents/objects
# - (you can have documents embedded/nested within other documents)

# %% [markdown]
# ## BSON
#
# MongoDB uses a binary-encoded format to store JSON documents
#
# this format is called BSON or binary JSON
#
# it's similar to JSON (it has embedded documents, arrays, etc.), but…
#
# - it has additional data types
# - more space efficient
# - it is faster to read from or write to the disk or memory

# %% [markdown]
# ## Documents and Collections
#
# Terminology:
#
# - key - a field name - analogous to a column in a relational database
# - value
# - document - a single object or record in our database
#   - consists of key value pairs
#   - similar to a single row in a relational database
# - collection - a group of documents
#   - analogous to a table in a relational databases

# %% [markdown]
# ## A Sample Collection of Bios of Famous Computer Scientists
#
# Let's take a [look](https://www.mongodb.com/docs/manual/reference/bios-example-collection/) at it.

# %% [markdown]
# ## MongoDB
#
# The open source version of MongoDB is called the Community Edition. You can run it in the cloud or on your local machine.
#
# It is client-server.
#
# The command-line client is called mongosh.
#
# There are are also various GUI clients:
#
# - MongoDB Compass is the official one
# - Robo 3T (community) and Studio 3T (paid)
# - Datagrip also supports connecting to MongoDb
#
# You can also run MongoDB in the cloud
#
# - MongoDB Atlas is MongoDB's own cloud service
# - Also runs on most major cloud providers like AWS, Azure, and Google Cloud

# %% [markdown]
# ## Some mongosh commands
#
# The following commands can be used to navigate, create and remove databases and collections
#
# - show databases - show available databases (remember, there can be more than one database)
# - use db - work with a specific database (if unspecified, the default database connected to is test)
# - show collections - once a db is selected, show the collections within the database
# - db.dropDatabase() - drop (remove) the database that you're currently in (must use first)
# - db.collectionName.drop() - drop (remove) the collection named collectionName
# - To get some inline help:
#   - help - get help on available commands

# %% [markdown]
# ## MongoDB Queries
#
# MongoDB uses a [query-by-example](https://en.wikipedia.org/wiki/Query_by_Example) style of querying. Query by Example is a technique that dates back to the 1970s. That means that you give MongoDB a pattern that you want to see in your results, and it returns the results that match your pattern. Pattern matching via [regular expressions](https://www.mongodb.com/docs/manual/reference/operator/query/regex/) is supported.

# %% [markdown]
# ## Performance and Suitability
#
# MongoDB claims performance advantages. But these are refuted by others. So it is hard to say which is true. I'm skeptical of any performance advantages, especially because all systems are moving targets and some of the studies aren't impartial.
#
# OnGres [found](https://www.enterprisedb.com/news/new-benchmarks-show-postgres-dominating-mongodb-varied-workloads) that PostgreSQL was faster than MongoDB, but MongoDB [disputes this](https://www.mongodb.com/blog/post/benchmarking-do-it-right-or-dont-do-it-at-all), saying that OnGres's methodology was poor. And then OnGres [critiqued](https://www.ongres.com/blog/benchmarking-do-it-with-transparency/) MongoDB's critique.
#
# The debate is not only over performance, but over the suitability for usage as a database at all. This [article](https://www.enterprisedb.com/blog/schema-later-considered-harmful) by Michael Stonebraker illustrates how the lack of a predefined schema can be a disadvantage. And this [article](https://www.enterprisedb.com/blog/compare-mongodb-vs-postgresql-join-command), also by Stonebraker, critiques MongoDB's join facilities.
#
# Google Spanner is an example of a relational system that scales comparably well to MongoDB and similar NoSQL systems.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:1.08em;font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Mongo (Jupyter Notebook)
#   </div>
# </div>

# %% [markdown]
# ##  MongoDB
#
# MongoDB is a Nosql database. Specifically, it's a document store:
#
# * a single record in Mongo is a document
# * a document is a bunch of key value pairs…
# * documents are similar to JSON / JavaScript objects or Python dictionaries
# * it's actually BSON, a binary version of JSON
# * for convenience, we can say that MongoDB uses JSON document to store records

# %% [markdown]
# ## JSON
#
# JSON (JavaScript Object Notation) is a data interchange format / file format that is composed of key value pairs.
#
# A single JSON document consists of:
#
# * curly braces
# * keys and values joined by :
# * key/value pairs separated by commas
# * all keys must be double quoted
# * values can be numbers, strings, arrays or other JSON documents/objects
# * (you can have documents embedded/nested within other documents)

# %% [markdown]
# ## BSON
#
# MongoDB uses a binary-encoded format to store JSON documents
#
# this format is called BSON or binary JSON
#
# it's similar to JSON (it has embedded documents, arrays, etc.), but…
#  * it has additional data types
#  * more space efficient
#  * it is faster to read from or write to the disk or memory

# %% [markdown]
# ## Documents and Collections
#
# Terminology:
#
# * key - a field name - analogous to a column in a relational database
# * value
# * document - a single object or record in our database
#     - consists of key value pairs
#     - similar to a single row in a relational database
# * collection - a group of documents
#     - analogous to a table in a relational databases

# %% [markdown]
# ## A Sample Collection of Bios of Famous Computer Scientists
#
# Let's take a [look](https://www.mongodb.com/docs/manual/reference/bios-example-collection/) at it.

# %% [markdown]
# ## MongoDB
#
# The open source version of MongoDB is called the Community Edition. You can run it in the cloud or on your local machine.
#
# It is client-server.
#
# The command-line client is called mongosh.
#
# There are are also various GUI clients:
#
# * MongoDB Compass is the official one
# * Robo 3T (community) and Studio 3T (paid)
# * Datagrip also supports connecting to MongoDb
#
# You can also run MongoDB in the cloud
#
# * MongoDB Atlas is MongoDB's own cloud service
# * Also runs on most major cloud providers like AWS, Azure, and Google Cloud

# %% [markdown]
# ## Some mongosh commands
#
# The following commands can be used to navigate, create and remove databases and collections
#
# * show databases - show available databases (remember, there can be more than one database)
# * use db - work with a specific database (if unspecified, the default database connected to is test)
# * show collections - once a db is selected, show the collections within the database
# * db.dropDatabase() - drop (remove) the database that you're currently in (must use first)
# * db.collectionName.drop() - drop (remove) the collection named collectionName
# * To get some inline help:
#     - help - get help on available commands

# %% [markdown]
# ## MongoDB Queries
#
# MongoDB uses a [query-by-example](https://en.wikipedia.org/wiki/Query_by_Example) style of querying. Query by Example is a technique that dates back to the 1970s. That means that you give MongoDB a pattern that you want to see in your results, and it returns the results that match your pattern. Pattern matching via [regular expressions](https://www.mongodb.com/docs/manual/reference/operator/query/regex/) is supported.

# %% [markdown]
# ## Performance and Suitability
#
# MongoDB claims performance advantages. But these are refuted by others. So it is hard to say which is true. I'm skeptical of any performance advantages, especially because all systems are moving targets and some of the studies aren't impartial.
#
# OnGres [found](https://www.enterprisedb.com/news/new-benchmarks-show-postgres-dominating-mongodb-varied-workloads) that PostgreSQL was faster than MongoDB, but MongoDB [disputes this](https://www.mongodb.com/blog/post/benchmarking-do-it-right-or-dont-do-it-at-all), saying that OnGres's methodology was poor. And then OnGres [critiqued](https://www.ongres.com/blog/benchmarking-do-it-with-transparency/) MongoDB's critique.
#
# The debate is not only over performance, but over the suitability for usage as a database at all. This [article](https://www.enterprisedb.com/blog/schema-later-considered-harmful) by Michael Stonebraker illustrates how the lack of a predefined schema can be a disadvantage. And this [article](https://www.enterprisedb.com/blog/compare-mongodb-vs-postgresql-join-command), also by Stonebraker, critiques MongoDB's join faciliies.

# %%
import os
import pymongo
from pymongo import MongoClient

# %%
client = MongoClient(os.getenv('MONGO_HOST'))

# %%
db = client['test']
db

# %%
person=db['person']
db.person.delete_many({})
db.person.insert_one({'first':'Bob','last':'Newhart'})

# %%
db.person.insert_one({'first':'Lucille','last':'Ball'})

# %%
for i in db.person.find({"last":"Newhart"}):
  print(i)

# %%
for i in db.person.find({}):
  print(i)

# %%
db.person.update_one({'last':'Newhart'}, {"$set": {'last':'Hartley'}})

# %%
for i in db.person.find({}):
  print(i)

# %%
db.person.delete_many({})
# now both records are gone
for i in db.person.find({}):
  print(i)

# %%
# creating a new collection called "Cat"
Cat=db['Cat']
db.Cat.delete_many({})

# %%
db.Cat.insert_one({"name":'Garfield', "lives":9})

# %%
for i in db.Cat.find({}):
  print(i)

# %%
for i in db.Cat.find({"lives":9}):
  print(i)

# %% [markdown]
# ## Finding Continued
#
# Inserting more, then using greater than!

# %%
db.Cat.insert_one({"name":"Cat in the Hat", "lives":2})
db.Cat.insert_one({"name":"Puss in Boots", "lives":5})
for i in db.Cat.find({'lives': {"$gt":4}}):
  print(i)

# %%
for i in db.Cat.find({}):
  print(i)

# %% [markdown]
# ## Another CRUD example

# %%
db.person.delete_many({})

# %%
db.person.insert_one({'first':'Abraham','last':'Lincoln'})
db.person.insert_one({'first':'Martha','last':'Lincoln'})
db.person.insert_one({'first':'Martha','last':'Smith'})
db.person.insert_one({'first':'Adam','last':'Smith'})

# %%
for i in db.person.find({'last':'Lincoln'}):
  print(i)

# %%
db.person.update_one({'last':'Lincoln'},{"$set": {'last':'Maslow'}})

# %%
for i in db.person.find({}):
  print(i)

# %%
db.person.insert_one({"phone number":"201-555-1212","email": "joe@gmail.com"})

# %%
for i in db.person.find({}):
  print(i)

# %% [markdown]
# ## An Aggregation Pipeline in MongoDB
#
# The following pipeline uses a collection of pizza orders. The aggregation pipeline first finds the medium pizza orders (similar to a SELECT in SQL) and then finds the total number of pizzas ordered by type of pizza, among the medium pizzas (similar to a group by with sum() in SQL)

# %%
pizza=db['pizza']

# %%
db.pizza.delete_many({})

# %% [markdown]
# ## Insert some pizza orders

# %%
db.pizza.insert_many([
   { "name": "Pepperoni", "size": "small", "price": 19,
     "quantity": 10, "date": "2021-03-13T08:14:30Z"  },
   { "name": "Pepperoni", "size": "medium", "price": 20,
     "quantity": 20, "date" : "2021-03-13T09:13:24Z" },
   { "name": "Pepperoni", "size": "large", "price": 21,
     "quantity": 30, "date" : "2021-03-17T09:22:12Z"  },
   { "name": "Pepperoni", "size": "medium", "price": 21,
     "quantity": 60, "date" : "2021-03-17T09:22:12Z"  },
   { "name": "Cheese", "size": "small", "price": 12,
     "quantity": 15, "date" : "2021-03-13T11:21:39.736Z"  },
   { "name": "Cheese", "size": "medium", "price": 13,
     "quantity":50, "date" :"2022-01-12T21:23:13.331Z"  },
   { "name": "Cheese", "size": "large", "price": 14,
     "quantity": 10, "date" : "2022-01-12T05:08:13Z"  },
   { "name": "Vegan", "size": "small", "price": 17,
     "quantity": 10, "date" : "2021-01-13T05:08:13Z"  },
   {  "name": "Vegan", "size": "medium", "price": 18,
     "quantity": 10, "date" :  "2021-01-13T05:10:13Z"  },
   {  "name": "Vegan", "size": "medium", "price": 18,
     "quantity": 20, "date" :  "2021-01-14T05:20:17Z"  }
]
)

# %% [markdown]
# ## Grab just the medium orders

# %%
for i in db.pizza.find({"size":"medium"}):
  print(i)

# %%
for i in db.pizza.aggregate( [
 # Stage 1: Filter pizza order documents by pizza size
   {
      "$match": { "size": "medium" }
   }
] ):
  print(i)

# %% [markdown]
# ## Grab the medium orders and then sum the quantity of pizzas by pizza name.

# %%
for i in db.pizza.aggregate( [
 # Stage 1: Filter pizza order documents by pizza size
   {
      "$match": { "size": "medium" }
   }
,
 # Stage 2: Group remaining documents by pizza name and calculate total quantity
   {
      "$group": { "_id": '$name', "totalQuantity": { "$sum": "$quantity" } }
   }
] ):
  print(i)

# %% [markdown]
# Exercise:
#
# Do the above aggregation in SQL, assuming columns name, size, and quantity.

# %% [markdown]
# ## Let's work with our sample enrollments again.
#
# Let's see how MongoDB can interact with Pandas.

# %%
import pandas as pd 
import json
enrollments=pd.read_csv("sample_enrollments.csv")
enrollments.head(5)

# %% [markdown]
# Let's extract just the unique courses and their data.

# %%
courses=enrollments[['course_number','course_title','meeting_time','loc']].drop_duplicates().reset_index(drop=True)
courses.head(10)

# %% [markdown]
# Let's extract just the unique professors and their data. We will also include a non-normalized column containing an array of their courses.

# %%
professors=enrollments[['professor_name','professor_office','course_number']].drop_duplicates().reset_index(drop=True)
professors

# %%
changes=['course_number']
cols=professors.columns.difference(changes).tolist() # remove the "course_number column"
print(cols)
professors=professors.groupby(cols)[changes].agg(list).reset_index()
professors.rename(columns={'course_number':'courses'},inplace=True)
professors.head(10)

# %% [markdown]
# Let's extract the unique students and add a column with a vector of their courses.

# %%
students=enrollments[['student_name','uni','year_in_school','course_number']].reset_index(drop=True)
changes=['course_number']
cols=students.columns.difference(changes).tolist()
students=students.groupby(cols)[changes].agg(list).reset_index()
students.rename(columns={'course_number':'courses'},inplace=True)
students.head(10)

# %%
import pprint

# %% [markdown]
# Create an enrollment database in MongoDB and a collection called "courses_m".

# %%
db=client['enrollments'] # creates a database

# %%
courses_m=db['courses_m']

# %%
db.courses_m.delete_many({})

# %% [markdown]
# Let's look at the courses dataframe as a dictionary, or actually a list of dictionaries, each of which is similar to a MongoDB document.

# %%
courses.to_dict('records')

# %% [markdown]
# We can then insert this list of dictionaries containing the courses data into the courses_m collection.

# %%
db.courses_m.insert_many(courses.to_dict('records'))

# %% [markdown]
# We can then query MongoDB and get the records back. Note that MongoDB has added a unique document _id to each document.

# %%
import pprint
for course in db.courses_m.find({}):
    pprint.pprint(course)

# %% [markdown]
# Similarly we can create a collection for the professors.

# %%
profs=db['profs']

# %%
db.profs.delete_many({})

# %% [markdown]
# And we can insert a list of dictionaries containing the professor information into MongoDB.

# %%
db.profs.insert_many(professors.to_dict('records'))

# %% [markdown]
# And then we can query MongoDB to get the data back.

# %%
for prof in db.profs.find():
  pprint.pprint(prof)

# %% [markdown]
# Create a MongoDB collection for the students.

# %%
students_m=db['students_m']

# %%
db.students_m.delete_many({}) # empty the collection out

# %% [markdown]
# Convert the students dataframe to a list of dictionaries and insert them in the collection.

# %%
db.students_m.insert_many(students.to_dict('records'))

# %% [markdown]
# Then we can query the collection and get the records back.

# %%
for student in db.students_m.find():
  pprint.pprint(student)

# %% [markdown]
# We can use a regular expression to find the students named "Mary."

# %%
import re
pattern=re.compile("^mary",re.IGNORECASE)
for student in students_m.find({"student_name":pattern}):
  pprint.pprint(student)

# %% [markdown]
# Let's take a look at the beginning of the enrollments data.

# %%
enrollments.to_dict('records')[:4]

# %%
enrollments

# %% [markdown]
# Let's change the index to a combination of the course number and uni (which would be a composite primary key for this table).

# %%
enrollments['cnUni']=enrollments['course_number']+" "+enrollments['uni']

# %%
enrollments.set_index(['cnUni'],inplace=True)

# %%
enrollments.drop(['course_number','uni'],axis=1,inplace=True)

# %%
enrollments.head(5)

# %% [markdown]
# Let's convert it to dictionary format.

# %%
import pprint
enrollment_dict=enrollments.to_dict('index')
print(type(enrollment_dict))
i=0
for key,value in enrollment_dict.items():
  print(key,value)
  i+=1
  if i==4:break

# %%
enrollments_m=db['enrollments']

# %%
db.enrollments.insert_many(enrollments.to_dict('records'))

# %%
for i in db.enrollments.find({}):
  print(i)

# %% [markdown]
# ## Alternatives to persisting pandas data in a database

# %% [markdown]
# Python offers its own facilities for object persistence including "shelve" and "pickle" which are more lightweight than persisting data to a MongoDB collection or a table in some SQL database.

# %%
import shelve
enrollments_persist=shelve.open("enrollments") # this creates a file called "enrollments.db"
for key in enrollment_dict.keys():
    enrollments_persist[key]=enrollment_dict[key]
enrollments_persist.close()

# %% [markdown]
# Shelve files are key-value stores like dictionaries. Here we re-open the persistent file and print out one value.

# %%
e2=shelve.open("enrollments")
print(e2["CSCI-UA-0201-003 mt6271"])
e2.close()

# %% [markdown]
# Pickle can serialize (convert to a byte stream and write to disk) any Python object. Unpickling can be insecure, so only unpickle trusted objects. Pickling is built into pandas.

# %%
enrollments.to_pickle("enrollments.pickle")

# %%
e3=pd.read_pickle("enrollments.pickle")
e3.head(2)

# %% [markdown]
# Another option for persisting data is to just convert it to JSON and write it out to a text file.

# %%
f=open("enrollments.json","w")
f.write(enrollments.to_json(orient='index'))
f.close()

# %%
f=open("enrollments2.json","w")
f.write(enrollments.to_json(orient='records',lines=True))
f.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Aggregation in SQL
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.7em 0.9em;font-size:0.72em;color:#6b6478;">
#     <b style="color:#b26a00;">Exercise link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">
#       &lt;paste URL here&gt;
#     </span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Survey
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.7em 0.9em;font-size:0.72em;color:#6b6478;">
#     <b style="color:#b26a00;">Exercise link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">
#       &lt;paste URL here&gt;
#     </span>
#   </div>
# </div>

# %% [markdown]
# ## Answer to Survey Question
#
# select name, sum(quantity) from pizza where size='Medium' group by name

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 32</div>
#   <div style="font-size:1.15em;font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Introduction to MongoDB
#   </div>
# </div>
