# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
#
#   /* Slide titles, px for the same reason. Every heading and every card in a
#      deck sits inside `.jp-RenderedHTMLCommon`, which JupyterLab sizes at 14px
#      -- NOT the 26px this theme puts on the slide. So the `1.45em` this rule
#      used to carry rendered at 20.3px, and the lecture title's `1.35em` at
#      18.9px, i.e. the title card came out SMALLER than the slide titles under
#      it and both sat within a couple of px of the 18px code. */
#   --dma-title-size: 22px;
#
#   /* Body prose. This is JupyterLab's own variable rather than a `--dma-` one:
#      `.jp-RenderedHTMLCommon` sizes itself from it, and everything inside a
#      rendered markdown cell inherits from there -- paragraphs, list items,
#      table cells, blockquotes. Setting it here lifts all of them at once, and
#      scoped to `.reveal` it changes the deck only, never the notebook editor.
#      It also gives the theme's remaining `em` values something sensible to
#      anchor to: inline code at `0.92em` and the small-caps card labels scale
#      with the prose instead of against JupyterLab's 14px default. The sizes
#      that must not move with it -- slide titles, code, output -- are all in px
#      above. */
#   --jp-content-font-size1: 17px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: var(--dma-title-size) !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:18px;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">22</span>
#     <span style="font-size:24px;font-weight:800;line-height:1.15;">Introduction to SQLite</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">10 content slides &nbsp;&middot;&nbsp; 53 live demos &nbsp;&middot;&nbsp; 12 in-class exercises</div>
# </div>

# %% [markdown]
# ## SQLite
#
# [SQLite](https://www.sqlite.org/) is a popular "embedded" database which does not use the client-server model but rather stores its data in an ordinary file on a computer. It is heavily used by many operating systems and applications. It supports much of the SQL standard. It is not an application but a C-language library which other developers can use in their apps.
#
# It has an amusing slogan: "Small. Fast. Reliable. Choose any three."
#
# I'm using it in this course because it is simple but features almost all of the significant features of SQL. SQLite is in heavy use in industry, so it is useful to have a knowledge of it; it not just a toy database.

# %% [markdown]
# ## SQLite Data Types
#
# SQLite supports five basic data types to store its column values:
#
# - NULL: for representing missing data
# - INTEGER: uses a variable amount of bytes depending on the value's magnitude
# - REAL: stores a floating point value in eight bytes
# - TEXT: a text string
# - BLOB: A "blob" of data (binary large object) which can be anything, stored just as it was input. Can be used to store images, for instance.

# %% [markdown]
# ## Creating Databases
#
# In other relational databases that use the client server model, like PostgreSQL or MySQL, databases are created using the "CREATE DATABASE" command. Each database server can host multiple databases. In SQLite, databases can be created at a command prompt, e.g.
#
# ```text
# sqlite3 test.db
# ```
#
# creates a database called "test.db" which is stored in an ordinary system file which can be sent to other machines or deleted. Switching databases is just a matter of opening a different database file.

# %% [markdown]
# ## Creating Tables in a Database
#
# Every database needs to have one or more tables in it. You can think of each table as similar to a pandas dataframe. It has one or more named columns. The columns can take on any of the types given above.
#
# In SQL, creating tables is done by giving a list of the names of the columns of the tables along with their types (one of the five above) in a CREATE TABLE statement. Some of the information that may be included in this statement is:
#
# - the name of the new table (required)
# - the name of each column in the table (required)
# - the type of each column (required)
# - a default value for a column (optional)
# - a PRIMARY KEY for the table, which can be in one or more columns (optional, but a good idea)
# - constraints on values (e.g. UNIQUE or NOT NULL) (optional, but often also a good idea)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Sample Movie Database
#   </div>
# </div>
#
# In the code below, I load a sample movies database called movies.db which has one table that I created with the following command:
#
# ```sql
# CREATE TABLE movie (
#     id integer PRIMARY KEY autoincrement,
#     title text,
#     director text,
#     year text,
#     runtime integer,
#     genre text,
#     budget real,
#     gross real
# );
# ```
#
# I ran this command in the database IDE DB Browser for SQLite. At this point, I will show you how I did that.
#
# The command below shows that it has the columns, but no data yet.

# %%
# the sqlite3 module allows you to access
# a sqlite database from Python
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies.db")

# following uses pandas to run an SQL query
# against the database
print(pd.read_sql_query("select * from movie", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Sample Movie Database: Populating a Table
#   </div>
# </div>
#
# There are several ways to insert data into a table in SQLite. For instance, you can use the command line and the SQLite ".import" statement to import from a CSV file. (In PostgreSQL, you would use the COPY command) Or you can use an database IDE; many of them support importing data.
#
# The code below populates the table with some data using the "INSERT INTO" SQL command. This command takes a list of tuples containing the data for the table.
#
# It then uses "select \* from movie" to output all the rows of the table.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
import shutil
shutil.copyfile("movies.db", "movies-scratch.db")
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies-scratch.db")
def execSQL(query,conn):
	conn.execute(query) # execute an SQL query
	conn.commit() # "commit" that query in order to make its action permanent
query='''
INSERT INTO movie (title, director, year, runtime, genre, budget, gross)
		VALUES
				('Blue Velvet', 'David Lynch', '1986-01-01', 120, 'Neo Noir Mystery Thriller', 6000000, 8600000),
				('Dune', 'David Lynch', '1984-01-01', 136, 'Science Fiction', 40000000, 30900000),
				('Strange Days', 'Kathryn Bigelow', '1995-01-01', 145, 'Science Fiction', 42000000, 8000000),
				('Point Break', 'Kathryn Bigelow', '1991-01-01', 122, 'Crime Thriller', 24000000, 83500000),
				('Zero Dark Thirty', 'Kathryn Bigelow', '2012-01-01', 157, 'Political Thriller', 40000000, 132800000),
				('Blade Runner', 'Ridley Scott', '1982-01-01', 117, 'Sci-Fi', 28000000, 33800000),
				('Blade Runner 2049', 'Denis Villeneuve', '2017-01-01', 163, 'Science Fiction', 185000000, 259200000),
				('Alien', 'Ridley Scott', '1979-01-01', 117, 'Sci-Fi', 11000000, 203600000),
				('Alien Covenant', 'Ridley Scott', '1982-01-01', 122, 'Science Fiction', 111000000, 240900000),
				('2046', 'Wong Kar-wai', '1982-01-01', 122, 'Drama', 12000000, 19500000),
				('Wonder Woman', 'Patty Jenkins', '2017-01-01', 141, 'Super Hero', 150000000, 821000000),
				('La Piel Que Habito (The Skin I Live In)', 'Pedro Almodóvar', '2011-01-01', 120, 'Horror', 13500000, 30800000),
				('Los Abrazos Rotos (Broken Embraces)', 'Pedro Almodóvar', '2009-01-01', 128, 'Romantic Thriller', 18000000, 31000000),
				('El Laberinto del Fauno (Pan''s Labyrinth)', 'Guillermo del Toro', '2006-01-01', 119, 'Dark Fantasy Horror', 19000000, 83300000),
				('Shape of Water', 'Guillermo del Toro', '2017-01-01', 123, 'Romantic Dark Fantasy Drama', 20000000, 195200000),
				('Pacific Rim', 'Guillermo del Toro', '2013-01-01', 132, 'Sci-Fi', 200000000, 411000000),
				('Hellboy', 'Guillermo del Toro', '2004-01-01', 122, 'Super Hero', 66000000, 99300000);
'''
# following uses pandas to run an SQL query
# against the database
execSQL(query,conn)
print(pd.read_sql_query("select * from movie", conn))

# %% [markdown]
# ## The SELECT Statement: Retrieving Data in SQL
#
# The command to query data in SQL is SELECT. The basic structure of a SELECT command is as follows:
#
# ```text
# SELECT [DISTINCT] columns
#   FROM table
#   WHERE condition
#   GROUP BY columns
#   HAVING condtion
#   ORDER BY column [ASC | DESC]
#   LIMIT offset, count
# ```
#
# SELECT and FROM are required; all of the rest are optional.
#
# The SELECT command used in the previous command is the simplest one, SELECT \* FROM MOVIE; it selects all of the columns and rows from the MOVIE table, the entire table.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Limiting the Output
#   </div>
# </div>
#
# If we just want the first 10 rows, we can use "select \* from movie limit 10".
#
# The query below uses a version of the database that already contains the data.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")

print(pd.read_sql_query("select * from movie limit 10", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting Some Columns and Rows
#   </div>
# </div>
#
# In the example below, we select just the title, director and genre where the genre contains the string "Thriller" somewhere in it.
#
# The SQL query is:
#
# select title, director, genre from movie where genre like '%Thriller'

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
print(pd.read_sql_query("select title, director, genre from movie where genre like '%Thriller'", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Duplicate Values
#   </div>
# </div>
#
# If we select just the director, we get duplicates, because some directors have more than one movie.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
print(pd.read_sql_query("select director from movie", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Removing Duplicates
#   </div>
# </div>
#
# If we add the DISTINCT keyword to the query in the last slide, it removes duplicates.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
print(pd.read_sql_query("select distinct director from movie", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Sorting
#   </div>
# </div>
#
# The query below selects the title, director and budget columns and sorts by director in ascending order and then by budget in descending order using ORDER BY.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")

print(pd.read_sql_query("select title, director, budget from movie order by director asc, budget desc", conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Grouping and Aggregating
#   </div>
# </div>
#
# In the example below, we use GROUP BY in conjunction with COUNT and ORDER BY to find out how many movies each director directed.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
print(pd.read_sql_query("select director, count(*) from movie group by director order by director", conn))

# %% [markdown]
# ## Aggregation Functions
#
# The following are the aggregation functions that can be used with GROUP BY in SQLite.
#
# - avg(X)
# - count(X) or count(\*)
# - group\_concat(X) or group\_concat(X,Y)
# - max(X)
# - min(X)
# - sum(X) and total(X) (have slightly different behavior in terms of treatment of NULL values)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting from Aggregated Output using HAVING
#   </div>
# </div>
#
# The query below selects just the movies with runtime greater than 125 and then averages up their budget by director, and then restricts using HAVING to those rows with an average budget of over $20 million, ordering the output by the director's name in ascending order.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select director, avg(budget) as avg_budget
from movie
where runtime>125
group by director
having avg_budget>20000000
order by director asc
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Group Concatenation
#   </div>
# </div>
#
# The query below uses GROUP BY with group\_concat to get one row per director, with a list of their movies.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select director, group_concat(title) as movie_list from movie
group by director order by director
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# ## SELECT: Order of Operations
#
# The SELECT command executes in the following order:
#
# 1. From: selects the table(s)
# 2. Where (if any) : applies conditions
# 3. Group by (if any): creates groups
# 4. Aggregations (if any): aggregates by groups, typically using a function like avg or max
# 5. Having (if any): conditions on the aggregated results
# 6. Select: select columns
# 7. Distinct (if any): apply this if specified
# 8. Order By (if any): apply order if specified
# 9. Limit (limit the number of records output)

# %% [markdown]
# ## SELECT With the WHERE Clause
#
# WHERE is used for filtering results
#
# - conditions can use operators like =, <> (not equal), >, <
# - you can also use LIKE with % representing wildcards to match on substrings
# - use col\_name IS NULL to check for a NULL value
# - multiple conditions can be put together with AND, OR, NOT
# - parentheses can be added to specify precedence

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Caution Regarding Group By
#   </div>
# </div>
#
# You will get strange results if you try to access a column that is not in the group by without using an aggregation function, as in the example below. We are selecting budget (as well as average budget), but there are multiple values of budget in each director group. SQLite gives us a random, unpredictable one of these values.
#
# Some database software will give an error if you try to do this. In any case, you should avoid queries like this because the results won't make sense.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select director, title, budget, avg(budget)
from movie group by director
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Sorting by More than One Column
#   </div>
# </div>
#
# You can sort by more than one column, as in the example below.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query='''
select title, director, gross from movie order by director desc, gross desc
'''

print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting with WHERE
#   </div>
# </div>
#
# Here we select just the science fiction movies.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, director, genre from movie where genre='Science Fiction'
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting with WHERE (2)
#   </div>
# </div>
#
# Here we select just the non-science fiction movies.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, director, genre from movie where genre<>'Science Fiction'
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting Using a Pattern
#   </div>
# </div>
#
# This example does a case-insensitive search for "thriller"; "like" searches in SQLite are case-insensitive.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, director, genre from movie where genre like '%thriller'
"""

print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Another Search Example
#   </div>
# </div>
#
# Here we search for thrillers not directed by Kathryn Bigelow.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, director, genre from movie
where genre like '%thriller' and director<>'Kathryn Bigelow'
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Calculated Columns
#   </div>
# </div>
#
# You can create a temporary calculated column and even order by it. Here we create a return on investment column and give it a temporary name roi. We then output movies sorted by director and within director by decreasing roi.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query='''
select title, director, round((gross-budget)/budget,2) as roi
from movie order by director, roi desc
'''

print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting on a Calculated Column
#   </div>
# </div>
#
# You can also select rows based on the calculated column. Here we select those movies where the return on investment is more than 100%.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, director, round((gross-budget)/budget,2) as roi
from movie where roi>1 order by roi
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Altering the Table
#   </div>
# </div>
#
# We can alter the table to add a permanent column which contains the return on investment (roi). Initially the values will all be null.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
import shutil
shutil.copyfile("movies2.db", "movies2-scratch.db")
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2-scratch.db")
def execSQL(query,conn):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
query='alter table movie add column roi real'
execSQL(query, conn)
query="select title, roi from movie"
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Altering the Table, Setting the Values
#   </div>
# </div>
#
# We can use an update statement to calculate and set the values of the new roi column.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
import shutil
shutil.copyfile("movies2.db", "movies2-scratch.db")
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2-scratch.db")
def execSQL(query,conn):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
query='alter table movie add column roi real'
execSQL(query, conn)
query='update movie set roi=((gross-budget)/budget)'
execSQL(query, conn)
query="select title, round(roi,2) from movie"
print(pd.read_sql_query(query, conn))

# %% [markdown]
# ## Scalar Functions in SQLite
#
# Round is one of the many [scalar functions](https://www.sqlite.org/lang_corefunc.html) supported by SQLite.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting in a Range
#   </div>
# </div>
#
# The code below selects the movies with a budget between $40 and $90 million.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="select title, budget from movie where (budget>=40000000) and (budget<=90000000)"
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting in a Range and Sorting
#   </div>
# </div>
#
# Here we select those same movies, but order them by descending budget.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
query="""
select title, budget from movie
where (budget>=40000000) and (budget<=90000000)
order by budget desc
"""
print(pd.read_sql_query(query, conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Fixing a Data Cleaning Issue
#   </div>
# </div>
#
# In the table, science fiction appears as both "Science Fiction" and "Sci-Fi". Let's fix this using the UPDATE command.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
import shutil
shutil.copyfile("movies2.db", "movies2-scratch.db")
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2-scratch.db")
def execSQL(query,conn):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent
query1="select title, genre from movie where genre='Science Fiction' or genre='Sci-Fi'"
print(pd.read_sql_query(query1, conn))
query2='update movie set genre="Science Fiction" where genre="Sci-Fi"'
execSQL(query2,conn)
print()
print(pd.read_sql_query(query1, conn))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       First exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: CREATE TABLE
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Second exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Saving an SQL Table to a Pandas Dataframe
#   </div>
# </div>
#
# The pandas read\_sql\_query method that we have been using allows you to save its result in a dataframe.
#
# Note you can connect to many SQL databases, not just SQLite, although the connection module will vary.
#
# Here we save the movies table in a dataframe called moviedf.

# %%
import sqlite3
import pandas as pd
conn=sqlite3.connect("movies2.db")
moviedf=pd.read_sql_query("select * from movie", conn, index_col='id')
print(moviedf.head(5))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Population Density
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Third exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Population Density Using SQL
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Fourth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Another Database: Oil Imports
#   </div>
# </div>
#
# Here we read some data on oil imports from a csv file into a pandas dataframe. Then we write the dataframe into a SQLite table using the pandas to\_sql method. Then we can read the data directly from SQL from Python. This uses the [SQLAlchemy](https://docs.sqlalchemy.org/en/20/) interface.
#
# Note that here the database that we connect to is initially empty since when we open it is it is not actually there; it is created, but it has no tables. We put a table in it with to\_sql.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
from pathlib import Path
Path("oil_import-scratch.db").unlink(missing_ok=True)
import sqlite3
import pandas as pd

def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)

conn=sqlite3.connect("oil_import-scratch.db")
oil_imports=pd.read_csv("oil_import.csv")
print(oil_imports.head(5))
oil_imports.to_sql('oil_imports',conn)
query="select * from oil_imports limit 5"
allrowsSelect(query,conn)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying the Oil Imports Database
#   </div>
# </div>
#
# Here we are using a version of the Oil Imports database in which the data has already been inserted.
#
# We find the month in each year that had the maximum number of barrels of oil were purchased, limiting to the top ten records.
#
# This requires the use of SELECT with GROUP BY, ORDER BY, and LIMIT.

# %%
import sqlite3
import pandas as pd

conn=sqlite3.connect("oil_import.db")
query='''
SELECT year, month, MAX(barrels_purchased) as Max_Barrels
FROM oil_imports
GROUP BY year
ORDER BY Max_Barrels DESC
LIMIT 10;
'''
print(pd.read_sql_query(query,conn))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Querying the Oil Imports Database Again
#   </div>
# </div>
#
# Here we find the maximum price by year for the years between 1975 and 1990, sorted by descending maximum price.

# %%
import sqlite3
import pandas as pd

conn=sqlite3.connect("oil_import.db")
query='''
SELECT year, MAX(unit_price) as maxprice
FROM oil_imports
GROUP BY year
HAVING year BETWEEN 1975 AND 1990 order by maxprice desc
'''
print(pd.read_sql_query(query,conn))

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Fifth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Deleting Tables and Data
#   </div>
# </div>
#
# You sometimes want to delete entire tables from a database or some or all of the rows of a table from a database.
#
# To delete rows, you use the "DELETE FROM" command with an optional "WHERE" clause. If there is no "WHERE" clause, then all of the rows are deleted. However, the table will still be there.
#
# To actually delete a TABLE, use the "DROP TABLE" command.
#
# Below, we create a small test database to experiment with this.

# %% [markdown]
# Create a database with one table.

# %%
import pandas as pd
import sqlite3
import os
try:
	os.remove("test.db") # remove db if already there
except:
	pass
conn=sqlite3.connect("test.db") # db is created initially empty

def execSQL(query,conn):
  conn.execute(query) # execute an SQL query
  conn.commit() # "commit" that query in order to make its action permanent

# create a table
query='''
CREATE TABLE students (
	uni text PRIMARY KEY,
	firstname text,
	lastname text
);
'''
# execute it
execSQL(query,conn)

# %% [markdown]
# Put some data in the table and examine it.

# %%
query='''
INSERT INTO students (uni, firstname, lastname)
	VALUES
    ('cb123','Charlie','Brown'),
    ('lvp546','Lucy','Van Pelt'),
    ('lvp124','Linus','Van Pelt'),
    ('sb421','Sally','Brown')
'''
execSQL(query,conn)
query='select * from students'
pd.read_sql_query(query,conn)

# %% [markdown]
# We can delete selected rows.

# %%
query="delete from students where lastname='Brown'"
execSQL(query,conn)
query='select * from students'
pd.read_sql_query(query,conn)

# %% [markdown]
# Or we can delete all rows. But even after we delete all rows, the table is still there, it just doesn't have any data in it.

# %%
query="delete from students"
execSQL(query,conn)
query='select * from students'
pd.read_sql_query(query,conn)

# %% [markdown]
# We have to drop the table to get rid of it. But even after dropping the table, the database is still there, but doesn't have any tables.

# %%
query="drop table students"
execSQL(query,conn)
try:
  query='select * from students'
  pd.read_sql_query(query,conn)
except:
  print("The table is not there.")

# %%
conn.close()

# %% [markdown]
# ## Introducing Joins in SQLite
#
# A join merges data from two or more tables. This can be done in several ways:
#
# - Cross Join: Merges every row in the first table with every row in the second. Rarely Used. Doesn't match values between tables.
#
# The following types of joins match on some common data and merge based on that.
#
# - Inner Join: Includes only rows found in both tables from both tables (intersection)
# - Left Outer Join: Includes all of the rows in the left table and matching rows in the right table.
# - Right Outer Join: Includes the matching rows in the left table and all rows in the right table. Not supported by SQLite.
# - Full Outer Join: Includes all the rows in both the left and right tables whether they match or not. Not supported by SQLite.

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Some Different Movie Data
#   </div>
# </div>
#
# Let's read in some different movie data to practice joins. This database has two tables, genre and movie, which are linked via genre\_id, which appears in both tables, and is the primary key of the genre table and a foreign key in the movie table.
#
# We read the tables in from csv files to dataframes and then use the to\_sql method to write them into an initially empty database.

# %%
# This example works on its own scratch copy of the data, so it runs the
# same way no matter which of the other examples you ran first.
from pathlib import Path
Path("movies2-scratch.db").unlink(missing_ok=True)
import pandas as pd
genre=pd.read_csv("genres.csv")
print(genre)
movie=pd.read_csv("movies2.csv")
print(movie)
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2-scratch.db")
genre.to_sql('genre',conn)
movie.to_sql('movie',conn)
query="select * from genre limit 3"
allrowsSelect(query,conn)
query="select * from movie limit 3"
allrowsSelect(query,conn)
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Cross Join
#   </div>
# </div>
#
# Here we run a cross join on the new movie data, which combines every row from the movie table with every row of the genres table.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
select movie_id, title, genre.genre_id, name
from movie cross join genre
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     An Inner Join
#   </div>
# </div>
#
# An inner join only joins matching values. This is often what you want.
#
# The following is an inner join which matches the two tables on the genre\_id field, which exists in both tables. The column genre\_id is the primary key of the genre table and a foreign key in the movie table.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
SELECT title, name as genre_name
  FROM movie
  INNER JOIN genre on movie.genre_id = genre.genre_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     An Inner Join Using Where
#   </div>
# </div>
#
# The same result as in the previous slide can be accomplished by listing the two tables involved and using the WHERE clause without the INNER JOIN keyword. The inner join is implicit in this case.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
SELECT title, name as genre_name
  FROM movie, genre
  WHERE movie.genre_id = genre.genre_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Left Outer Join
#   </div>
# </div>
#
# A left outer join (also called just a left join) includes all the rows in the left table along with the matching rows in the right table. If no row matches on the right, null values are inserted.
#
# There are also right outer joins (which include everything in the right table) and full outer joins (which include everything in both tables) but these are not supported by SQLite. There are workarounds to this, though.
#
# For instance, you can make a right outer join into a left one by just swapping which tables are left and right.
#
# The following is a left outer join that includes all the rows in the left table (movie), even those without a matching genre id. The right table is genre.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
SELECT title, name as genre_name
  FROM movie
  LEFT JOIN genre on movie.genre_id = genre.genre_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Flipping the Tables
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Sixth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Genres with No Matching Movies
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Seventh exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Self Joins
#   </div>
# </div>
#
# A self join joins a table with itself. Let's try to use this to find the pairs of movies that were released in the same year. We create two aliases for the table, a and b, and join on matching years.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2.db")
query="""
SELECT a.title as first_movie_title,
b.title as second_movie_title, a.year
FROM movie as a
INNER JOIN movie as b on a.year = b.year
ORDER BY a.year, a.title, b.title
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Removing Movies Matching Themselves
#   </div>
# </div>
#
# The trouble with the previous query is that movies match themselves. Let's make sure the movie ids are different.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
SELECT a.movie_id, a.title, b.movie_id, b.title, a.year
FROM movie as a INNER JOIN movie as b ON a.year = b.year
WHERE a.movie_id != b.movie_id
ORDER BY a.year, a.movie_id, b.movie_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Removing Duplicates
#   </div>
# </div>
#
# There is still one thing wrong. Each movie pair appears twice in both orders. We can fix this by making sure that the first movie id is less than the second.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("movies2_with_genre.db")
query="""
SELECT a.movie_id, a.title, b.movie_id, b.title, a.year
FROM movie as a INNER JOIN movie as b ON a.year = b.year
WHERE a.movie_id < b.movie_id
ORDER BY a.year, a.movie_id, b.movie_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     The Khans and Khagans Database
#   </div>
# </div>
#
# The Khans were the family of Genghis Khan. They ruled the Mongol Empire of the 13th and 14th centuries, which was one of the largest empires in history. Khan also became a high noble title, and some of the Khans were Khagans or Great Khans who ruled as emperors. We have two tables, of Khans and Khagans.
#
# Interesting fact: Genghis Khan may have [more descendants](https://www.discovermagazine.com/the-sciences/1-in-200-men-direct-descendants-of-genghis-khan) than any other person in history, perhaps as many as 16 million.
#
# Thanks to Prof. Amos Bloomberg on whose work the following draws.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query="select * from khans"
print(pd.read_sql_query(query,conn))
query="select * from khagans"
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Khans that became Khagans
#   </div>
# </div>
#
# Let's find all of the Khans that became Khagans. The column khan\_id exists in both tables so can be used to join the two tables.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query='''
select * from khans inner join khagans
on khans.khan_id=khagans.khan_id
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Shorthand Form for the Join
#   </div>
# </div>
#
# We can also use the shorthand form at the right to do the join done in the previous slide.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query="""
select * from khans, khagans
where khans.khan_id=khagans.khan_id
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Swapping the Order of the Tables.
#   </div>
# </div>
#
# If we switch the order of the tables, we get the same data, but the order of the columns is flipped.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query='''
select * from khagans,khans
on khans.khan_id=khagans.khan_id
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Finding Everyone's Khagan Status
#   </div>
# </div>
#
# Let's find all of the Khans irrespective if they were Khagans, merging in their Khagan ID, which will be missing (NULL, or NaN or None in Pandas) if they weren't a Khagan. We can use a left join to do this.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query='''
select * from khans left join
khagans on khans.khan_id=khagans.khan_id
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Eighth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Data Integrity
#   </div>
# </div>
#
# The query below gives no results.
#
# This is because there are no records in the Khagan table that reference a Khan in the Khan table which is not found in that table. This is because these tables have good data integrity; every Khagan is supposed to reference a valid Khan. But if that wasn't the case, say if you deleted a record from the Khan table who was also a Khagan, you would get a result from the query.

# %%
import pandas as pd
import sqlite3
def allrowsSelect(query, conn):
  cursor = conn.execute(query)
  for row in cursor:
    print(row)
conn=sqlite3.connect("khans.db")
query='''
SELECT * FROM
khagans LEFT JOIN khans
ON khans.khan_id=khagans.khan_id
WHERE khans.khan_id IS NULL
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Full Outer Joins
#   </div>
# </div>
#
# Full outer joins include all the rows in both tables, with those rows with matching keys joined. Where there is no match, NULLs are inserted.
#
# If we have tables A and B, then the full outer join is the union of:
#
# - a left outer join of A (left) with B (right), which includes all the records of A including those matching on the key (and those that don't)
# - a partial left outer join of B (left) with A (right) which only includes those records in B which don't match a record in A. (This is the same as a partial right outer join of A and B.)
#
# if A is the Khans table and B is the Khagans table, we can do that with the query below. Note in this case the second left outer join is in fact empty, since as we have seen there are no Khagans that don't match a record in the Khan table, but that doesn't have to be the case with data more generally.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("khans.db")
query='''
SELECT * FROM
khans LEFT JOIN khagans
ON khans.khan_id=khagans.khan_id
UNION ALL
SELECT * FROM
khagans LEFT JOIN khans
ON khans.khan_id=khagans.khan_id
WHERE khans.khan_id IS NULL
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Self or Reflexive Joins
#   </div>
# </div>
#
# Self or reflexive joins are joins of a table on itself. Some cases where you might want to do this:
#
# - a table of employees that shows employee manager relationships, where the managers themselves are also in the employee table (and have their own manager, except for the CEO.)
# - a table of people who might have a spouse in the same table
#
# In our table of Khans, each Khan's parents and children are often found in the same table.
#
# The query below produces a list of all the fathers and their children. Each father has multiple rows if he has more than one child.
#
# Note that we create aliases for the columns and the tables to distinguish between the two copies of the same table.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("khans.db")
query='''
SELECT parents.name AS father, children.name as child
FROM khans AS parents INNER JOIN khans AS children
ON parents.khan_id = children.father_id
order by father
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Counting the Children of Each Father
#   </div>
# </div>
#
# We can modify the query in the last slide using group by to count how many kids each father had.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("khans.db")
query='''
SELECT parents.name AS father,
COUNT(children.name) AS num_kids
FROM khans AS parents INNER JOIN khans AS children
ON parents.khan_id = children.father_id
GROUP BY father
ORDER BY num_kids DESC
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Listing the Children of Each Mother
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <b style="color:#b26a00;font-size:0.72em;">Exercise Link:</b>
#     <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;
#                  font-size:0.72em;color:#6b6478;">&lt;PrairieLearn URL here&gt;</span>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Children of Khagans
#   </div>
# </div>
#
# What if we want to find the list of children of Khans that were also Khagans? This requires a self join on the Khans table combined with an inner join on the Khagans table.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("khans.db")
query='''
SELECT parents.name AS father,
GROUP_CONCAT(children.name) AS children,
COUNT(children.name) AS num_kids
FROM khagans, khans as parents, khans as children
WHERE parents.khan_id = children.father_id
AND parents.khan_id=khagans.khan_id
GROUP BY father
ORDER BY num_kids DESC
'''
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     New York City Jobs Data
#   </div>
# </div>
#
# The database loaded below comes from the New York City open jobs website. The database has two tables, a list of jobs and a list of city agencies.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("NYCJobs.db")
print(pd.read_sql_query("select job_id, agency_id, title from jobs limit 5",conn))
print(pd.read_sql_query("select salary_range_from, salary_range_to from jobs limit 5",conn))
print(pd.read_sql_query("select * from agencies limit 5",conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Most Frequently Occurring Titles
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Ninth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Jobs by Agency
#   </div>
# </div>
#
# The query below shows the number of  jobs that are advertised by each agency, ordered by descending numbers of jobs.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("NYCJobs.db")
query="""
select agencies.title as agency_title, count(jobs.title) as count
from jobs,agencies
where agencies.id=jobs.agency_id
group by agencies.title
order by count desc
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Agencies by Highest Paying Job
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Tenth exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Data Cleaning Issue
#   </div>
# </div>
#
# Let's examine the minimum salaries by agency. There appear to be some data cleaning issues here. Some salaries are zero and some appear to be hourly.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("NYCJobs.db")
query="""
select agencies.title as agency_name, jobs.title as job_title,
min(jobs.salary_range_from) as min_salary
from agencies, jobs
where agencies.id=jobs.agency_id
group by agencies.title
order by min_salary asc limit 10
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     City and Country Data
#   </div>
# </div>
#
# In the database below, there are two tables, one which contains data on countries and the other on cities.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("cc.db")
print(pd.read_sql_query("select * from countries limit 5",conn),"\n")
print(pd.read_sql_query("select * from cityPopulations limit 5",conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Share of Country Population in Large Cities
#   </div>
# </div>
#
# For the countries that contain one of these large cities, what share of their total population lives in the city areas of any of the cities?
#
# To answer this question, the query below first finds the total urban population for each of the countries.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("cc.db")
query="""
select country,group_concat(City) as cityList,
total(MetroPopulation2018) as urbanpop
from cityPopulations
group by country
order by urbanpop desc
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Share of Country Population in Large Cities (2)
#   </div>
# </div>
#
# Having found the total urban population of each country, we can find the share that lives in one of the large cities in the list.
#
# This involves a subquery. We will be seeming more examples of subqueries soon. Note the subquery is given a temporary.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("cc.db")
query="""
select countries.country,population, cityList, urbanpop,
urbanpop/population as largeCityShare
from (select country, group_concat(City) as cityList,
total(MetroPopulation2018) as urbanpop
from cityPopulations
group by country) as totCityPop, countries
where totCityPop.Country=countries.country
order by largeCityShare desc
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Share of Country Population in Large Cities (3)
#   </div>
# </div>
#
# The query below does the same thing as in the previous slide, but using the WITH syntax to define the temporary table.
#
# This syntax is a bit more readable.

# %%
import pandas as pd
import sqlite3
conn=sqlite3.connect("cc.db")
query="""
with totCityPop as (
select country, group_concat(City) as cityList,
total(MetroPopulation2018) as urbanpop
from cityPopulations
group by country
)
select countries.country,population, cityList, urbanpop,
urbanpop/population as largeCityShare
from totCityPop, countries
where totCityPop.Country=countries.country
order by largeCityShare desc
"""
print(pd.read_sql_query(query,conn))
conn.close()

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Exercise: Densest Cities
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       11th exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713068</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 22</div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Introduction to SQLite
#   </div>
# </div>
