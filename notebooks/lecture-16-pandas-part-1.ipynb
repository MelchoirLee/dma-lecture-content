# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
#
#   /* Slide titles, px for the same reason. Every heading and every card in a
#      deck sits inside `.jp-RenderedHTMLCommon`, which JupyterLab sizes at 14px
#      -- NOT the 26px this theme puts on the slide. So the `1.45em` this rule
#      used to carry rendered at 20.3px, and the lecture title's `1.35em` at
#      18.9px, i.e. the title card came out SMALLER than the slide titles under
#      it and both sat within a couple of px of the 18px code. */
#   --dma-title-size: 22px;
#
#   /* Body prose. This is JupyterLab's own variable rather than a `--dma-` one:
#      `.jp-RenderedHTMLCommon` sizes itself from it, and everything inside a
#      rendered markdown cell inherits from there -- paragraphs, list items,
#      table cells, blockquotes. Setting it here lifts all of them at once, and
#      scoped to `.reveal` it changes the deck only, never the notebook editor.
#      It also gives the theme's remaining `em` values something sensible to
#      anchor to: inline code at `0.92em` and the small-caps card labels scale
#      with the prose instead of against JupyterLab's 14px default. The sizes
#      that must not move with it -- slide titles, code, output -- are all in px
#      above. */
#   --jp-content-font-size1: 17px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: var(--dma-title-size) !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:18px;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">16</span>
#     <span style="font-size:24px;font-weight:800;line-height:1.15;">Pandas Part 1</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">4 content slides &nbsp;&middot;&nbsp; 63 live demos</div>
# </div>

# %% [markdown]
# ## Pandas
#
# Pandas ("Python data analysis") is a Python module that contains data structures and tools for working with data.
#
# It has a lot of numpy-like functionality in it, like vector-based operations
#
# However, pandas specializes in dealing with tabular data composed of mixed data types, while an numpy array can usually hold a single data type (although there is a newer type of numpy array, a structured array, that can hold more than one.)
#
# Also, pandas has an explicit idea of named columns and an index column that indexes the rows. Numpy just has indeces and slices (which pandas has as well.)

# %% [markdown]
# ## Types in Pandas
#
# - Series: a one-dimensional, labeled array
# - DataFrame: two dimensional data structure (with named columns, like a spreadsheet with a header row)
#   - each column of a DataFrame is itself a Series
# - Index

# %% [markdown]
# ## Pandas Series
#
# - a one-dimensional labeled array
# - the associated labels are collectively referred to as the index
# - Series properties:
#   - values: the actual data in the Series
#   - index: the labels for the data in the Series

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a Series
#   </div>
# </div>
#
# There are several ways to create a series
#
# - use a single positional argument, which may be a ndarray or a Python sequence like a list, to specify the series's values.
# - two positional arguments, with the second containing the index labels
# - passing in keyword arguments for data and index
# - passing in a dictionary with the keys as labels and the values as the series' values
#
# In the example below, we initialize a pandas series with a list.

# %%
import pandas as pd
import numpy as np
# without the index specified, you get numerical index values starting with zero
# the index is displayed in the first column and the values in the second
series =pd.Series([7,8,9])

print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Initializing a Pandas Series Object using a NumPy array
#   </div>
# </div>
#
# We can see below that we can use a NumPy array to create a series. In the previous slide, we used a list. Either works fine.

# %%
import pandas as pd
import numpy as np
# get the same thing if we use a ndarray
series =pd.Series(np.array([7,8,9]))
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Storing String Data in a Series
#   </div>
# </div>
#
# A series can hold string data as well as numeric data, as shown in the example below.

# %%
import pandas as pd
import numpy as np
# can also use string data
series=pd.Series(["Batman","Superman","Robin"])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Pandas Series Can Contain Mixed Data Types
#   </div>
# </div>
#
# Below, we see that a Pandas series can hold mixed data types.

# %%
import pandas as pd
import numpy as np
# unlike numpy, data can be mixed type
series=pd.Series(["Batman","Spiderman",42])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a Pandas Series with a Custom Index in Pandas
#   </div>
# </div>
#
# We can set a custom index, rather than the default numeric one. In the example below, each state is indexed by its two-letter postal abbreviation (a string).
#
# Note that the index is not unique in this case. It doesn't have to be. In NumPy, indexes must be numeric and unique.

# %%
import pandas as pd
import numpy as np
# and unlike numpy, labels can be non-numeric and even non-unique
cities=pd.Series(["Stamford","Albany","Buffalo","Hartford"],["CT","NY","NY","CT"])
print(cities)
print()
print(cities['NY'])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a Series with Keyword Arguments
#   </div>
# </div>
#
# Below, we create a pandas Series using the keyword argument "data".
#
# Since the index isn't specified, we get a default numeric index starting with zero.

# %%
import pandas as pd
# you can use keyword arguments instead, data only or both data and index
series=pd.Series(data=[7,8])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Series Creation with Explicit Index
#   </div>
# </div>
#
# In the example below, we use keyword arguments to specify both the data and the index.
#
# The lengths of the sequences specifying the data and the index must be the same.

# %%
import pandas as pd
import numpy as np
# lengths of the data and the index must be the same
series=pd.Series(index=['A','B','C'],data=[7,8,9])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Mismatched Index Length in Creation of a Pandas Series
#   </div>
# </div>
#
# Here's what happens when the lengths don't match: you get a runtime error.

# %%
import pandas as pd
try:
  pd.Series([7,8,9], index=['A','B'] )
except ValueError as e:
  print(e)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a Series from a Dictionary
#   </div>
# </div>
#
# You can use a dictionary to create a series where the dictionary keys represent the values of the index and the dictionary values represent the Series values, as shown below.

# %%
import pandas as pd
# can initialize with a dictionary
# keys become index labels, values are the Series values
series=pd.Series({'B':'bat','A': 'ant'})
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Specifying the Index of a Series Redundantly
#   </div>
# </div>
#
# In the example below, the index is specified twice, which is unnecessary but possible. It is specified once in the dictionary keys and once by the second argument to the Series method call.

# %%
import pandas as pd
# can redundantly specify index
series=pd.Series({'A':'ant', 'B':'bat'},['A','B'])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Omitting an Index Key Found in the Dictionary
#   </div>
# </div>
#
# Here we specify the index twice, but since the key "B" is not included in the list of index values specified as the second argument, only the index value "A" and its corresponding value "ant" is stored in the series.

# %%
import pandas as pd
import numpy as np
# if a key from the dictionary data is not listed in the index, its value is not included in the Series.
series=pd.Series({'A':'ant', 'B':'bat'},['A'])
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Unspecified Values Become Missing
#   </div>
# </div>
#
# Note that if an index key is specified but the data is not, the data value becomes NaN (which stands for "Not a Number" and is one of [the missing value representations in Pandas](https://pandas.pydata.org/docs/user_guide/missing_data.html).) Missing data representations allow us to specify that we don't know what the value is. Note this can mean two things: that we don't know what the value is, or that there is no value in existence. For instance, there is a King of England, but maybe we don't know their name. But there is no King of the United States ...
#
# This is shown below in that there is no value associated with "C" as the value of the index.
#
# The "isnull" method checks if series values are null; the notnull method checks if they are not.

# %%
import pandas as pd
import numpy as np
# if an index label is not in the dictionary, it is included as NaN missing data.
x=pd.Series({'A':'ant','B':'bat'},['A','C'])
print(x)
print()
print(pd.isnull(x))
print()
print(pd.notnull(x))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Accessing the Index and Values of a Series through Attributes
#   </div>
# </div>
#
# The index and values properties of a series can be used to get the labels and data of a series, as shown in the example below.

# %%
import pandas as pd
s=pd.Series([7,8,9],['x','y','z'])
print("Series values:",s.values)
print(type(s.values)) # the values are stored in a NumPy ndarray
print("Series index:",s.index)
print(type(s.index)) # the index is stored in its own type of object
print(list(s.index)) # but it can be converted to an ordinary list

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Indexing into a Series
#   </div>
# </div>
#
# Indexing into a series is similar to indexing a one-dimensional ndarray in NumPy. You just specify the index value in square brackets, as shown in the example below.

# %%
import pandas as pd
import numpy as np
s=pd.Series([7,8,9,10],list('xyxz'))
print(f"Series:\n{s}")
print("Single Value:",s['y'])
print(type(s['y']))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting Multiple Elements in a Pandas Series
#   </div>
# </div>
#
# You can specify more than one row in a Series by passing it a list of labels, as shown in the example below.
#
# The result is also a Series.

# %%
import pandas as pd
s=pd.Series([7,8,9,10],list('xyxz'))
print(s[['y','z']])
print(type(s[['y','z']]))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Series Indexing with Duplicate Labels
#   </div>
# </div>
#
# If you duplicate a series index value when you index into it, that row is duplicated, as in the example below.

# %%
import pandas as pd
import numpy as np
s=pd.Series([7,8,9,10],list('xyxz'))
# repeating a label repeats that value
print(s[['y','y','z']])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Series Selection by Index and Position
#   </div>
# </div>
#
# You can index into a Series using either the index value or the numerical row number (starting at zero.) So in the example below, both methods of indexing give the same result.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
s=pd.Series([2,3,4,5],list('abcd'))
print(s)
print(s['b'])
print(s[1]) # deprecated
print(s.iloc[1]) # equivalent

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Slicing a Pandas Series
#   </div>
# </div>
#
# You can slice by either row label or using a numerical row number. The former is inclusive on the right; the latter is exclusive.
#
# So the two examples below give the same result.

# %%
import pandas as pd
import numpy as np
s=pd.Series([2,3,4,5],list('abcd'))
# can slice by position or by label
# label slicing is inclusive at the end
print(s[1:3])
print(s['b':'c'])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Performing Arithmetic on a Pandas Series
#   </div>
# </div>
#
# In the example below, we create a Series and then subtract 2 from all of its values.

# %%
import pandas as pd
import numpy as np
s=pd.Series([2,3,4,5],list('abcd'))
print(s-2)

# NumPy equivalent:
x=np.array([2,3,4,5])
print(x-2)
print(type(x-2))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Scalar Multiplication of Series Elements
#   </div>
# </div>
#
# Similar to the last slide, but here we double every element of the Series.

# %%
import pandas as pd
import numpy as np
s=pd.Series([2,3,4,5],list('abcd'))
print(2*s)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Adding a Series to Itself in Pandas
#   </div>
# </div>
#
# If we add a Series to itself, it is equivalent to doubling it.

# %%
import pandas as pd
s=pd.Series([2,3,4,5],list('abcd'))
print(s+s)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Series Arithmetic with Label Alignment
#   </div>
# </div>
#
# When two series are added, matching labels are aligned, and the associated values are added, as in the example below.

# %%
import pandas as pd
import numpy as np
s1=pd.Series([1,2],['x','y'])
s2=pd.Series([3,4],['y','x'])
print(f"First Series:\n{s1}")
print(f"\nSecond Series:\n{s2}")
print(f"\nSum:\n{s1+s2}")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     A Missing Index Value Leads to Missing Value When Two Series are Added
#   </div>
# </div>
#
# In the example below, index value 'x' is present in both but the other two labels are only available in one of the series. So the other two labels have a missing value when the two series are added.

# %%
import pandas as pd
s1=pd.Series([1,2],['x','y'])
s2=pd.Series([6,3],['x','z'])
# for addition, labels must be present in both Series
print(s1+s2)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Comparing Series Values to a Scalar in Pandas
#   </div>
# </div>
#
# When a pandas series is compared to a single scalar value, a Series containing True or False values is returned, as in the example below.

# %%
import pandas as pd
s1=pd.Series([6,3],['x','z'])
# Comparisons vectorized
print(s1==6)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Element-Wise Series Comparison
#   </div>
# </div>
#
# The example below compares two pandas Series element-wise to check for equality. The result is another Series with appropriate True or False values.

# %%
import pandas as pd
# Series compared by value
s1=pd.Series([1,2],['x','y'])
s2=pd.Series([1,3],['x','y'])
print(s1==s2)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Matching Series Index Labels are Required for Comparisons
#   </div>
# </div>
#
# It is important that two series have identical sets of labels in order to be compared. If not, a runtime error will be generated as in the example below.

# %%
import pandas as pd
import numpy as np
# need identical labels to compare
s1=pd.Series([1,2],['x','y'])
s2=pd.Series([1,9],['x','z'])
try:
  s1==s2
except ValueError as e:
  print(e)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Boolean Indexing in a Pandas Series
#   </div>
# </div>
#
# You can use a boolean array to filter a pandas series, as in the example below.

# %%
import pandas as pd
import numpy as np
# as was the case with a numpy ndarray, you can filter with a Boolean list
s = pd.Series([2, 3, 4, 5])
print(s)
print()
# select just the first and third rows:
print(s[[True, False, True, False]])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Filtering a Pandas Series for Odd Values
#   </div>
# </div>
#
# In the example below, we use a conditional expression to filter and extract just the odd values.

# %%
import pandas as pd
import numpy as np
# as was the case with a numpy ndarray, you can filter with a Boolean list
s = pd.Series([2, 3, 4, 5])
# or can filter with an expression
# only odd values
print(s[s%2==1])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Applying the Modulus Operator to a Series
#   </div>
# </div>
#
# If we apply the modulus operator to the series, we get a series consisting of the remainders.

# %%
import pandas as pd
import numpy as np
# as was the case with a numpy ndarray, you can filter with a Boolean list
s = pd.Series([2, 3, 4, 5])
# this creates a series of the remainers (here zero or one)
print(s%2)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Conditional Filtering in Pandas Series
#   </div>
# </div>
#
# This code applies a conditional filter to a Series.

# %%
import pandas as pd
import numpy as np
s = pd.Series([2, 3, 4, 5])
# this filter gives us only the values below 4
print(s[s<4])

# %% [markdown]
# ## DataFrames
#
# - a rectangular table of data
# - can think of it also as an ordered collection of columns that have names
#   - each column is a Series
#   - so like a dictionary of Series objects where the column names are the keys
# - DataFrame index are row names
# - DataFrame columns are column names
# - DataFrame data is the data in the table
# - data, index, and columns can be specified when making a DataFrame

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating DataFrames
#   </div>
# </div>
#
# - positional arguments
#   - using an ndarray or other sequence
#   - using a dictionary
# - using keyword arguments
# - mixing positional and keyword arguments
#
# In the example below, we create a dataframe with two columns of data. The column and row names are not specified so the default numbering from zero is used.

# %%
# only data
import pandas as pd
print(pd.DataFrame([[1, 2, 3], [4, 5, 6]]))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a DataFrame with Specified Row Labels
#   </div>
# </div>
#
# Here we specify the data and the names for the rows (index).

# %%
import pandas as pd
# only data and index
df=pd.DataFrame([[1, 2, 3], [4, 5, 6]], ['r1', 'r2'])
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Initializing a DataFrame with Column and Row Labels
#   </div>
# </div>
#
# In this example, we set both the column and the row labels.

# %%
import pandas as pd
# all three
dataframe=pd.DataFrame( [[1, 2, 3], [4, 5, 6], [7, 8, 9]],  ['r1', 'r2', 'r3'],  ['A', 'B', 'C'])
print(dataframe)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a DataFrame and a Series with Labels in Pandas
#   </div>
# </div>
#
# Below we see how to create a DataFrame with specified row (index) and column labels, and a Series with an specified index.

# %%
import pandas as pd
# all three
dataframe=pd.DataFrame( [[1, 2, 3], [4, 5, 6], [7, 8, 9]],  ['r1', 'r2', 'r3'],  ['A', 'B', 'C'])
print(dataframe)
series=pd.Series({'r1':6,'r2':8})
print(series)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Creating a DataFrame from a Nested Dictionary
#   </div>
# </div>
#
# This code snippet demonstrates how to create a pandas DataFrame from a nested dictionary structure. Outer keys represent column names, while inner keys are used for row (index) names.

# %%
import pandas as pd
# nested dictionary
# outer keys are column names
# inner keys are row (index) names
dataframe=pd.DataFrame({
    "colA": {'r1': 6, 'r2': 7},
    "colB": {'r1': 8, 'r2': 9}
})
print(dataframe)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Creation with Automatic Index Creation
#   </div>
# </div>
#
# The code creates a DataFrame using lists for data and explicitly names the columns. Since the row names are not specified, pandas automatically generates numerical ones.

# %%
import pandas as pd
# can mix positional and keyword arguments
# here index is left out so is generated automatically
x=pd.DataFrame([[1, 2, 3], [4, 5, 6]],
     columns=['A', 'B', 'C'])
print(x)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Attributes
#   </div>
# </div>
#
# Dataframes have values, index, and columns attributes.
#
# The type of the dataframe which will be set to the type that can accommodate all of the values in it; this will often be different for different columns.
#
# In this example, the data is stored as NumPy integers.

# %%
import pandas as pd
# can mix positional and keyword arguments
# here index is left out so is generated automatically
x=pd.DataFrame([[1, 2, 3], [4, 5, 6]],
     columns=['A', 'B', 'C'])
print(x)
print(x.values)
print(type(x.values)) # numbers stored in NumPy type
print(x['A'][0]) # first value in first column
print(type(x['A'][0])) # type of first value in first column

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Examining the Index
#   </div>
# </div>
#
# The example below shows the index attribute of a dataframe. It contains the row tables which here are integers. The index is a generator-style object similar to a ordinary Python range object.

# %%
import pandas as pd
# can mix positional and keyword arguments
# here index is left out so is generated automatically
x=pd.DataFrame([[1, 2, 3], [4, 5, 6]],
     columns=['A', 'B', 'C'])
print(x.index)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Examining the Columns of a DataFrame
#   </div>
# </div>
#
# The columns attribute contains the column names, as shown below.
#
# It is stored in a list-like object which is not actually a Python list although it can be converted into one.

# %%
import pandas as pd
# can mix positional and keyword arguments
# here index is left out so is generated automatically
x=pd.DataFrame([[1, 2, 3], [4, 5, 6]],
     columns=['A', 'B', 'C'])
print(x.columns)
print(list(x.columns))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Column Data Types
#   </div>
# </div>
#
# The dtypes attribute gives you the type of each column. In this case, they are all the same.

# %%
import pandas as pd
# can mix positional and keyword arguments
# here index is left out so is generated automatically
x=pd.DataFrame([[1, 2, 3], [4, 5, 6]],
     columns=['A', 'B', 'C'])
print(x.dtypes)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Accessing DataFrame Columns
#   </div>
# </div>
#
# In the example below, we extract one of the columns of a dataframe, which is a series object.
#
# The name attribute of the series gives the column name of that column in the dataframe from which it was extracted.

# %%
import pandas as pd
x=pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
# Getting a single column
# result is a Series
print(x)
print(x['foo'])
print(x['foo'].name)
print(type(x['foo']))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Selecting Multiple Columns
#   </div>
# </div>
#
# Extracting multiple columns from a DataFrame creates a smaller DataFrame.

# %%
import pandas as pd
x=pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
# pulling out more than one column results in another, smaller DataFrame
print(x[['foo','bar']])
print(type(x[['foo','bar']]))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Column Rearrangement
#   </div>
# </div>
#
# You can reorder the columns of a dataframe and even duplicate them if desired, as shown in the example below.

# %%
import pandas as pd
x=pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
print("Original dataframe:")
print(x)
# you can also rearrange the columns and repeat them if desired
print("Another dataframe made out of the first one:")
print(x[['bar','bar','foo']])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Non-Existent DataFrame Columns Cause an Error
#   </div>
# </div>
#
# The code below shows what happens when you try to access a dataframe column that does not exist.

# %%
import pandas as pd
x=pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
# if a column doesn't exist, you get an error
try:
  x[['bar','dne']]
except KeyError as e:
  print(e)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Slicing by Rows
#   </div>
# </div>
#
# In the example below, we extract the first two rows of the dataframe using numerical slicing similar to what you would do in ordinary Python or in NumPy.

# %%
import pandas as pd
d = pd.DataFrame({"cA": {'r1': 1, 'r2': 2, 'r3': 3},
                  "cB": {'r1': 4, 'r2': 5, 'r3': 6},
                  "cC": {'r1': 7, 'r2': 8, 'r3': 9}})
print("Whole DataFrame:")
print(d)
# slicing gives rows
# first two rows
print("First Two Rows:")
print(d[:2])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Extracting Rows with Boolean Lists
#   </div>
# </div>
#
# The example below uses a Boolean list to extract specific rows from a dataframe, here the first and third.

# %%
import pandas as pd
d = pd.DataFrame({"cA": {'r1': 1, 'r2': 2, 'r3': 3},
                  "cB": {'r1': 4, 'r2': 5, 'r3': 6},
                  "cC": {'r1': 7, 'r2': 8, 'r3': 9}})
print("Entire dataframe:")
print(d)
# can also use Booleans to extract rows
# e.g. first and third row
print("Just first and third rows:")
print(d[[True, False, True]])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Filtering Dataframes using Conditional Expressions
#   </div>
# </div>
#
# The example extracts those rows where the value of the first column (cA) is not 2.
#
# The expression translates to a boolean vector.
#
# As we will see, this is similar to the following SQL:
#
# select \* from d where cA!=2
#
# where d is a table in an SQL-based relational database.

# %%
import pandas as pd
d = pd.DataFrame({"cA": {'r1': 1, 'r2': 2, 'r3': 3},
                  "cB": {'r1': 4, 'r2': 5, 'r3': 6},
                  "cC": {'r1': 7, 'r2': 8, 'r3': 9}})
print("Original Dataframe:")
print(d)
# or using an expression
# give me the rows where the value in column cA is not 2
# similar to SQL "select * from d where cA!=2"
print("Conditional Produces Boolean Vector:")
print(d['cA']!=2)
print("Extracted Dataframe")
print(d[d['cA']!=2])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Index- or Slice-Based Value Assignment in a Series
#   </div>
# </div>
#
# In this example, we create a series and then show how to update its values using indexing or slicing. Either can be used.

# %%
import pandas as pd
s=pd.Series(range(2,7),list('abcde'))
print("Original Series:")
print(s)
s['a']=100 # change value of first row
s['b':'d'] =200 # change value of middle three rows
print("New Series:")
print(s)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Updating a DataFrame
#   </div>
# </div>
#
# The example below creates a dataframe and then changes all values in the 'foo' column to 77.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
print("Original DataFrame:")
print(df)
# reset an entire column
df['foo']=77
print("Modified DataFrame:")
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Using a List to Update a Dataframe Column
#   </div>
# </div>
#
# In the example below, we update the values of a column of a dataframe using a list.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
print("Original Dataframe:")
print(df)
# reset using a list
df['foo']=[99,100]
print("Modified Dataframe:")
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Updating a Dataframe Column using a Series
#   </div>
# </div>
#
# In this example, we update a dataframe column using a series.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
print(f"Original Dataframe\n{df}")
# reset using a series
df['foo']=pd.Series([8,9])
print(f"Modified Dataframe\n{df}")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Assigning Series to DataFrame Columns
#   </div>
# </div>
#
# The code below assigns a new Series to a column in a DataFrame. This example shows assigning a Series to the 'foo' column, aligning by index, with missing values handled gracefully.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
    index=['r1', 'r2'],
    columns=['foo', 'bar', 'baz'])
# note missing r2 is set to NaN
print(df)
# and r3 ignored
df['foo'] = pd.Series([100, 200], ['r1', 'r3'])
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Length Mismatch
#   </div>
# </div>
#
# Here, we try to update a dataframe column with a list, but the dataframe column has two values and the list has three values. Therefore, it fails and the dataframe is not modified.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
    index=['r1', 'r2'],
    columns=['foo', 'bar', 'baz'])
# lengths must match when assigning
try:
  df['foo']=[100, 101, 102]
except ValueError as e:
  print(e)
print(df)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Updating a Dataframe Using a Conditional Expression
#   </div>
# </div>
#
# In the example below, we select those rows where the value of cA is greater than one and reset all of the values of those rows (which are the second and third rows) to zero.

# %%
import pandas as pd
# can also use Boolean selection when assigning
d = pd.DataFrame({"cA": {'r1': 1, 'r2': 2, 'r3': 3},
                  "cB": {'r1': 4, 'r2': 5, 'r3': 6},
                  "cC": {'r1': 7, 'r2': 8, 'r3': 9}})
print(f"Original Dataframe:\n{d}")
print(d['cA'] > 1)
d[d['cA'] > 1] = 0
print(f"Modified Dataframe:\n{d}")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Adding Columns; Reordering Columns
#   </div>
# </div>
#
# In the example below, we add a new column to a dataframe (at the end by default) and then we print the new dataframe out using a different column order.

# %%
import pandas as pd
# can add columns
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
print(f"Original Dataframe:\n{df}")
df['qux'] = [20, 30]  # qux is new
print(f"Modified Dataframe with New Column:\n{df}")
df2=df[['qux','bar','foo','baz']]
print(f"Modified Dataframe With a Different Column Ordering:\n{df2}")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Dropping a Column
#   </div>
# </div>
#
# In the example below, we use the drop method to remove a column from a dataframe.
#
# The drop method can drop either columns or rows based on the value of the axis parameter, where axis=0 means rows and axis=1 means columns.
#
# Unless you specify inplace=True, the method will create a copy. If you do specify inplace=True, it will destructively modify the existing object.

# %%
import pandas as pd
# can add columns
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
df['qux'] = [20, 30]  # qux is new
print(f"Original Dataframe:\n{df}")


# dropping columns
# need to specify axis
# rows is axis 0
# columns is axis 1
# need to specify inplace if you don't want to just create a copy
# with the column dropped but want to destructively remove the column
#df=df.drop('bar',axis=1)
df.drop('bar',axis=1,inplace=True)
print(f"Modified Dataframe with Column Removed:\n{df}")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Deleting DataFrame Columns with &quot;del&quot;
#   </div>
# </div>
#
# You can also use "del" to delete a column. This is a general Python keyword used to delete objects.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
     columns=['foo', 'bar', 'baz'])
df['qux'] = [20, 30]  # qux is new

print(f"Original Dataframe:\n{df}")

# can also use "del" to delete a column
del df['baz']
print(f"Modified Dataframe:\n{df}")

a=4 # create a integer object
print(a) # print it
del a # delete it
try:
    print(a)
except:
    print("Object was deleted.")

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Accessing DataFrame Rows with loc
#   </div>
# </div>
#
# In the example below, we use the "loc" method to extract the second row from a dataframe. The extracted object is a series.

# %%
import pandas as pd
# use loc to grab rows
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
    columns=['foo', 'bar', 'baz'])
print(df)
# loc returns series, here the second row
print(df.loc[1])
print(type(df.loc[1]))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Extracting a Single Value from a DataFrame
#   </div>
# </div>
#
# Here, we combine the loc method and column indexing to get a single value from a dataframe. Here, it is the 8 in the second row and the column named "bar". The number has been stored as a NumPy integer.

# %%
import pandas as pd
# use loc to grab rows
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
    columns=['foo', 'bar', 'baz'])
print(df)
# this grabs a single value
print(df.loc[1]['bar'])
print(type(df.loc[1]['bar']))

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     DataFrame Transposition
#   </div>
# </div>
#
# If we transpose a dataframe using the "T" attribute, the rows become the columns and vice versa.

# %%
import pandas as pd
df = pd.DataFrame([[4, 5, 6], [7, 8, 9]],
    columns=['foo', 'bar', 'baz'])
# tranposing
# columns become rows, rows columns
print(df)
print(df.T)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Index Structure
#   </div>
# </div>
#
# The index of a DataFrame or Series is an object that:
#
# - holds the row labels
# - is immutable
# - can be shared among objects (more than one dataframe or series)

# %%
import pandas as pd
d = pd.DataFrame({"colA": {'r1': 6, 'r2': 7},
                  "colB": {'r1': 8, 'r2': 9}})
print(d)
idx = d.index
print(idx)

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Accessing Index Elements
#   </div>
# </div>
#
# We can index into elements of a index object, as shown below.

# %%
import pandas as pd
d = pd.DataFrame({"colA": {'r1': 6, 'r2': 7},
                  "colB": {'r1': 8, 'r2': 9}})
idx = d.index
print(idx)
print(idx[0])

# %% [markdown]
# <div style="
#     border-left:10px solid #0b6a70;background:#e6f5f6;
#     border-radius:0 10px 10px 0;padding:0.75em 1.1em;margin-bottom:0.6em;">
#   <span style="font-size:0.58em;font-weight:800;letter-spacing:0.16em;
#                text-transform:uppercase;color:#0b6a70;">
#     &#128200; Live Example
#   </span>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#241c2c;margin-top:0.2em;">
#     Indexes are Immutable
#   </div>
# </div>
#
# Indexes are immutable. Trying to modify them will cause an error, as shown in the code example below.

# %%
import pandas as pd
d = pd.DataFrame({"colA": {'r1': 6, 'r2': 7},
                  "colB": {'r1': 8, 'r2': 9}})
idx = d.index
print(idx)
try:
  idx[0]='something'
except TypeError as e:
  print(e)

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 16</div>
#   <div style="font-size:var(--dma-title-size, 22px);font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Pandas Part 1
#   </div>
# </div>
