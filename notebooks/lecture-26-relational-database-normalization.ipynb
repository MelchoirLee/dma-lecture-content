# %% [markdown]
# <style>
# /* ==== DMA lecture deck theme (NYU violet) ============================== */
# .reveal {
#   --dma-violet: #57068c;
#   --dma-violet-deep: #3a0460;
#   --dma-ink: #241c2c;
#   --dma-muted: #6b6478;
#   font-size: 26px !important;
#   color: var(--dma-ink);
#
#   /* One monospace size for the deck, in px on purpose -- see the note above
#      the rules that use it. This is the only knob for resizing code; a code
#      cell and the output it produces are deliberately the same size, since
#      they are the same monospace material and any difference between them
#      reads as a mistake. */
#   --dma-code-size: 18px;
# }
# /* Slides are top-aligned (center: false), so without this the first heading
#    sits flush against the top edge; the bottom pad clears the footer bar. */
# .reveal .slides > section,
# .reveal .slides > section > section {
#   padding: 22px 10px 46px 10px !important;
#   box-sizing: border-box;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal .jp-RenderedHTMLCommon h2,
# .reveal .jp-RenderedHTMLCommon h3, .reveal .jp-RenderedHTMLCommon h4,
# .reveal h1, .reveal h2, .reveal h3, .reveal h4 {
#   color: #3a0460 !important;
#   text-transform: none !important;
#   letter-spacing: -0.01em;
#   font-weight: 700 !important;
#   text-align: left;
# }
# .reveal .jp-RenderedHTMLCommon h1, .reveal h1 { font-size: 1.9em !important; }
# .reveal .jp-RenderedHTMLCommon h2, .reveal h2 {
#   font-size: 1.45em !important;
#   border-bottom: 3px solid #f3ecfa !important;
#   padding-bottom: 0.25em !important;
#   margin-bottom: 0.7em !important;
# }
# .reveal .jp-RenderedHTMLCommon h3, .reveal h3 {
#   font-size: 1.15em !important;
#   color: #57068c !important;
# }
# .reveal .jp-RenderedHTMLCommon p, .reveal .jp-RenderedHTMLCommon li,
# .reveal p, .reveal li { line-height: 1.45; text-align: left; }
# .reveal .jp-RenderedHTMLCommon ul, .reveal .jp-RenderedHTMLCommon ol,
# .reveal ul, .reveal ol { display: block; margin-left: 1.1em; }
# .reveal .jp-RenderedHTMLCommon li, .reveal li { margin-bottom: 0.35em; }
# .reveal li::marker { color: #57068c; font-weight: 700; }
# .reveal .jp-RenderedHTMLCommon strong, .reveal strong {
#   color: #3a0460 !important;
# }
# .reveal .jp-RenderedHTMLCommon a, .reveal a {
#   color: #57068c !important;
#   text-decoration: underline;
# }
# .reveal .jp-RenderedHTMLCommon blockquote, .reveal blockquote {
#   border-left: 4px solid #57068c !important;
#   background: #f3ecfa !important;
#   padding: 0.6em 1em !important;
#   box-shadow: none !important;
#   font-style: normal !important;
#   width: 100%;
# }
# /* inline code (block code keeps the editor/pygments styling) */
# .reveal .jp-RenderedHTMLCommon :not(pre) > code, .reveal :not(pre) > code {
#   background: #f3ecfa !important;
#   color: #3a0460 !important;
#   padding: 0.08em 0.34em !important;
#   border-radius: 4px !important;
#   font-size: 0.92em !important;
# }
# .reveal .jp-InputArea-editor {
#   border-left: 4px solid #57068c !important;
#   border-radius: 0 6px 6px 0;
# }
# /* Long source lines must wrap, not run off the side of the slide.
#    `.cm-*` covers the live CodeMirror editors RISE presents; `.highlight pre`
#    covers the static Pygments markup that `nbconvert --to slides` emits. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .jp-InputArea-editor .cm-line,
# .reveal .highlight pre,
# .reveal pre code {
#   white-space: pre-wrap !important;
#   overflow-wrap: anywhere;
#   word-break: break-word;
# }
# /* ...and `pre-wrap` on its own is not enough for the CodeMirror editors:
#    CodeMirror sizes `.cm-content` to `max-content`, so there is no width for the
#    text to wrap against -- the editor simply grows wider than the slide and the
#    overflow is clipped, losing the end of the line. Constraining the width is
#    what actually makes it wrap. This only became visible once the code was sized
#    for a projector below: at the old 10.4px even a 100-character line still fit. */
# .reveal .jp-InputArea-editor .cm-scroller {
#   overflow-x: hidden !important;
# }
# .reveal .jp-InputArea-editor .cm-content {
#   width: 100% !important;
#   max-width: 100% !important;
# }
# /* Code and its output must be sized in absolute units, not `em`.
#    An `em` here resolves against two different parents: CodeMirror's editor
#    carries JupyterLab's `--jp-code-font-size` (13px), while an output `<pre>`
#    inherits from the slide, which this theme sets to 26px and RISE grows to
#    41.6px. The old `0.8em` / `0.74em` therefore rendered as 10.4px of source
#    against 30.8px of output -- the output nearly three times the code, though
#    the stylesheet read as though it were slightly smaller. One absolute value
#    for both is what keeps them honest. */
# .reveal .jp-InputArea-editor .cm-content,
# .reveal .highlight pre,
# .reveal pre code {
#   font-size: var(--dma-code-size) !important;
#   line-height: 1.35 !important;
# }
# .reveal .jp-OutputArea-output pre {
#   white-space: pre-wrap !important;
#   font-size: var(--dma-code-size) !important;
# }
# /* Keep plots large but bounded, so a figure does not fill the whole slide. */
# .reveal .jp-OutputArea img { max-height: 55vh; width: auto; max-width: 100%; }
# /* Let a slide scroll when its content is taller than the viewport -- running a
#    demo cell adds output and routinely overflows.
#    `.reveal` itself is `overflow: hidden`, so without this the overflow is just
#    clipped and the rest of the slide is unreachable. RISE's own `scroll: true`
#    config is supposed to do this but does not reliably apply, so own it here.
#    Scoped to `.present` to leave off-screen slides out of the layout work, and
#    deliberately NOT applied to `.jp-OutputArea`: a nested scroll box inside a
#    scrolling slide means the wheel scrolls the wrong thing. One scroller. */
# .reveal .slides > section.present,
# .reveal .slides > section > section.present {
#   overflow-y: auto !important;
#   overflow-x: hidden;
#   max-height: 100vh;
# }
# .reveal .jp-Cell { padding: 2px 0 !important; }
# .reveal .jp-RenderedHTMLCommon table { font-size: 0.85em !important; }
# .reveal .jp-RenderedHTMLCommon img { margin: 0 auto; }
# /* footer bar supplied via notebook `rise` metadata */
# .dma-footer {
#   position: fixed; bottom: 0; left: 0; right: 0;
#   padding: 6px 22px;
#   font-size: 15px;
#   color: #ffffff;
#   background: linear-gradient(90deg, #3a0460 0%, #57068c 100%);
#   display: flex; justify-content: space-between; align-items: center;
#   font-family: -apple-system, BlinkMacSystemFont, "Segoe UI", sans-serif;
#   z-index: 30;
# }
# .dma-footer .dma-course { opacity: 0.78; }
# .dma-footer .dma-lecture { font-weight: 600; }
# </style>
#
# <div style="
#     background:linear-gradient(135deg,#3a0460 0%,#57068c 55%,#7b1fa2 100%);
#     color:#fff;border-radius:14px;padding:2.2em 2em 1.8em 2em;
#     box-shadow:0 10px 30px rgba(87,6,140,0.28);">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;opacity:0.82;">
#     CS 0479 · Data Management and Analysis
#   </div>
#   <div style="display:flex;align-items:baseline;gap:0.55em;margin-top:0.5em;">
#     <span style="
#         font-size:1.05em;font-weight:800;background:rgba(255,255,255,0.16);
#         border:2px solid rgba(255,255,255,0.5);border-radius:10px;
#         padding:0.08em 0.5em;line-height:1.25;">26</span>
#     <span style="font-size:1.35em;font-weight:800;line-height:1.15;">Relational Database Normalization</span>
#   </div>
#   <div style="height:3px;width:110px;background:rgba(255,255,255,0.65);
#               border-radius:2px;margin:0.9em 0 0.7em 0;"></div>
#   <div style="font-size:0.62em;opacity:0.85;">29 content slides &nbsp;&middot;&nbsp; 3 in-class exercises</div>
# </div>

# %% [markdown]
# ## Review: Defining a Relational Database
#
# The term relational database doesn't stem from the fact that a database contains entities and their relationships.
#
# - instead, this terminology comes from the idea of a relation: a mathematical notion of what's essentially a table
# - so… a relational database is a collection of "relations" (a bunch of tables)
# - it's a little more nuanced than this, as relations have certain properties
# - most of those properties are directly applicable to the tables that represent them
# - this idea of a relational data model came from Edgar (E.F.) Codd in the early 1970's… and has been refined by others since…

# %% [markdown]
# ## Relations
#
# A relation can be defined as:
#
# - a table with columns (called attributes) and rows (called tuples)
# - an actual row of data is an instance of a relation (like an instance of an entity)
# - That just seems like a regular old table or a spreadsheet… what's new?
#
# The rows and columns must have certain properties (a DBMS will enforce these properties using constraints!)

# %% [markdown]
# ## Columns
#
# - columns must have unique names within a table (though, two different tables can have a column with the same name… and we can use aliasing to deal with this if both tables and their common columns are used in the same query)
# - the values in a column must be from a domain (that is, columns have a type)
# - when working with columns, the column position has no meaning (in practice, there is an ordering necessary when running certain queries, but this ordering does not affect the meaning of the data; the columns could be in any order an mean the same thing)

# %% [markdown]
# ## Rows
#
# - again, as we've described entities, the intersection of a column and row can only contain a single value.
# - there are no duplicate rows in a relation (hence, primary keys)
# - once again, like columns, rows can be viewed in any order (position does not affect meaning)

# %% [markdown]
# ## Normalization
#
# Normalization is the process of structuring a relational database to:
#
# - reduce redundant data / use less space
# - improve quality and integrity of data
# - make it easier to change data (avoid insert, update and delete anomalies)
# - allow for growth, evolution of data (reduce the need for restructuring tables completely when new data is introduced)
# - make referential integrity constraints easier to enforce
# - create clear and easy-to-understand structure that closely models the situation that the data represents

# %% [markdown]
# ## History of Normalization Theory
#
# This process was proposed by Edgar F Codd, in a paper called "A Relational Model of Data for Large Shared Data Banks"
#
# - Codd added more "normal forms" in subsequent works
# - and eventually collaborated with Raymond F. Boyce
# - CJ Date's works also added to the interpretation of modeling data

# %% [markdown]
# ## Normalization Controversy
#
# As both relational databases and the process of normalization have evolved, some concepts are actively being debated
#
# - for example, atomicity is cited in the original work, but its meaning is actually up for interpretation (how atomic?)
#   - a string 'hello', can be decomposed into individual characters, but should it?
#   - timestamp can be decomposed into year, month, day, hours, minutes and seconds)
# - does null violate a rule of only having a set data type for a column or is it accepted as a special marker for denoting missing values
#
# With that said, keep practicality and the goals of normalization in mind rather than a rigid adherence to rules or a philosophical viewpoint

# %% [markdown]
# ## First Normal Form (1NF)
#
# The first normal form specifies:
#
# - no repeating groups
#   - meaning of repeating groups has evolved since original paper / article
#   - it can mean… no repeated columns or columns that contain multiple values (atomicity)
#   - basically, when none of a relation's domains (types of columns) have a set as a possible value
#   - every row and col intersection only contains one value from the domain (again, atomic)
# - attributes are defined and…
# - attributes depend on a primary key

# %% [markdown]
# ## First Normal Form (2)
#
# Another way to look at it is… 1NF is related to the shape of a record type:
#
# - all rows must have same number of fields
# - atomicity - a single column can't have multiple values
#   - 123-456-7890, 555-555-5555
#
# Some additional attributes of 1NF:
#
# - ordering of columns or rows shouldn't be relevant
# - no duplicate rows (primary key again!)

# %% [markdown]
# ## An Example
#
# Are any of these tables in first normal form?
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/gCY9V47v2qi1FJx7p13vca4A.png" alt="" style="max-width:100%;width:651px;height:auto;"></div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Survey
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       First exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## An Example (2)
#
# Are any of these tables in first normal form?
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/uNWbpGbzXjmEgTin0yEVxeas.png" alt="" style="max-width:100%;width:556px;height:auto;"></div>
#
# No, none of them are.
#
# - attributes should depend on the primary key
# - there should be no repeating groups/values should be atomic

# %% [markdown]
# ## Another Example
#
# Is the following table in First Normal Form?
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/gWLos9yEJ4vwmhtQtwaPNueg.png" alt="" style="max-width:100%;width:252px;height:auto;"></div>
#
# Yes.
#
# - note that the primary key is a combination of course and netid
# - probably better as multiple tables

# %% [markdown]
# ## Second Normal Form (2NF)
#
# A relation is in second normal form if:
#
# 1. it's in 1NF
# 2. AND there are no partial dependencies
#   - a partial dependency is when a non-prime attribute has a functional dependency on a part of composite primary key (or even on a candidate key)
# 3. if a table has a primary key that consists of only one column, it's already in 2NF
# 4. deals with most insertion / deletion anomalies left over from 1NF

# %% [markdown]
# ## Superkeys
#
# A superkey is any set of attributes that can identify a row. Trivially, the set of all attributes in a table is a superkey. Some of these attributes are most likely extraneous (are not needed to identify a row) but nevertheless can form part of a superkey

# %% [markdown]
# ## Candidate Keys
#
# A candidate key is a minimal superkey, that is, a superkey that doesn't contain a smaller superkey.
#
# There may be several candidate keys in a table. You select one of the candidate keys to be the primary key; hence the name "candidate" since each candidate key is eligible to serve as the primary.
#
# An irrelevant joke:
#
# "If nominated, I will not run ... If elected, I will not serve."

# %% [markdown]
# ## Functional Dependencies
#
# A [functional dependency](https://opentextbc.ca/dbdesign01/chapter/chapter-11-functional-dependencies/) is one when one attribute's value depends on / is determined by another attribute's value.
#
# - if you have two attributes, X and Y…
# - for every valid instance of X, that value of X uniquely determines the value of Y
# - Y is functionally dependent on X if every row having the same value X has the same value for Y
# - or, more simply: if you know the value of X, you can determine the value of Y
# - note two different values for X may produce the same Y

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     A Question on Functional Dependencies
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Second exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## Is this table in 2NF?
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/XDNLfdc5BNeieddtb4ooalOI.png" alt="" style="max-width:100%;width:452px;height:auto;"></div>

# %% [markdown]
# <div style="
#     border:2px solid #b26a00;border-left:10px solid #b26a00;
#     background:#fff6e6;border-radius:12px;padding:1.3em 1.5em;">
#   <div style="font-size:0.6em;font-weight:800;letter-spacing:0.16em;
#               text-transform:uppercase;color:#b26a00;">
#     &#129514; In-Class Exercise
#   </div>
#   <div style="font-size:1.15em;font-weight:800;color:#241c2c;margin:0.45em 0 0.9em 0;">
#     Question on 2NF
#   </div>
#   <div style="background:#fff;border:2px dashed #b26a00;border-radius:8px;
#               padding:0.8em 1em;">
#     <a href="https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070" target="_blank" rel="noopener"
#        style="font-size:1.05em;font-weight:800;color:#b26a00;
#               text-decoration:underline;">Exercise Link</a>
#     <div style="font-size:0.7em;color:#241c2c;margin-top:0.45em;">
#       Third exercise in PrairieLearn list
#     </div>
#     <div style="font-size:0.6em;color:#6b6478;margin-top:0.5em;
#                 overflow-wrap:anywhere;">
#       If the hyperlink doesn't work, paste this link into your browser:
#       <span style="font-family:ui-monospace,SFMono-Regular,Menlo,monospace;">https://us.prairielearn.com/pl/course_instance/220030/assessment/2713070</span>
#     </div>
#   </div>
# </div>

# %% [markdown]
# ## Is this table in 2NF? (answer)
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/XDNLfdc5BNeieddtb4ooalOI.png" alt="" style="max-width:100%;width:452px;height:auto;"></div>
#
# Remember it needs to be in 1NF and contain no partial dependencies, that is, attributes that depend on just part of the key.
#
# 1. Candidate keys:
#   - a composite key: netid, course number
#   - a composite key: last, course number (not good because it depends on this data; other data could have duplicated last names)
# 2. Name a partial dependency
#   - first depends on netid or last
#   - course name depends on course number

# %% [markdown]
# ## Are we in 2NF yet?
#
# The solution is to separate into two tables and break up the composite key. Will this work?
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/gEU3DZgPebe50NSb1Kln6oQA.png" alt="" style="max-width:100%;width:612px;height:auto;"></div>
#
# - The primary key of the student table must be composite now (netid, course num)
# - But we still have a partial dependency because, for instance, last name is dependent on netid but not course number
# - Therefore we need to move course\_num into a different table.

# %% [markdown]
# ## Now we are in 2NF
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/SYkoPDXZfbxXdhIl7WcNZG0O.png" alt="" style="max-width:100%;width:628px;height:auto;"></div>
#
# - We moved the course num into a third table
# - The student and course tables each have a single column as the primary key
# - We added a "join" table containing only keys to represent the many-to-many relationship between the other two tables.
# - There are no longer any partial dependencies, that is, nothing that depends on only part of a key.

# %% [markdown]
# ## Third Normal Form (3NF)
#
# A relation is in third normal form if:
#
# 1. It's in 2NF
# 2. No non-prime attribute is dependent on the primary key through another non-prime attribute
# 3. If there is only one non-key attribute, it is already in 3NF.
#
# For instance, one might have a table with the following columns: employee, department, and location. If the employee field is the key, and the employee field determines the department, and the location is determined by the department, then rule #2 above is violated. The information about location is duplicated each time the department appears in the table.

# %% [markdown]
# ## A Violation of 3NF
#
# Consider the following table. Let's assume we are at a small school and the course numbers determine the department, that is, each course number is used by only one department. (This is not the case at NYU.)
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/9dlguCtnANH1fJ3MwcERBMhc.png" alt="" style="max-width:100%;width:355px;height:auto;"></div>
#
# Since, in this scenario, dept is determined by course\_num, which is the primary key, and dept description is dependent on the course\_num through dept, the table is not in 3NF.

# %% [markdown]
# ## Now it is in 3NF
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/FflpmXxtQGXhibWoRzhvVWZp.png" alt="" style="max-width:100%;width:386px;height:auto;"></div>
#
# We created a dept id which is dependent on course number. This now becomes the primary key of a second table and a foreign key in the first one.

# %% [markdown]
# ## The Normalization "Pledge"
#
# 2NF and 3NF deal with the relationships between keys and non-keys
#
# - Via Bill Kent's [A Simple Guide to Five Normal Forms](https://dl.acm.org/doi/10.1145/358024.358054)
# - "[Every] non-key [attribute] must provide a fact about the key, the whole key, and nothing but the key.
#
# Does this cover 1NF, 2NF, and 3NF? Yes.
#
# - 1NF: "the key" implies we have a key that uniquely identities each record
# - 2NF: "the whole key" means we have no partial dependencies, that is, attributes that are dependent on only part of the key
# - 3NF: "nothing but the key" means it does not depend on non-key attributes.

# %% [markdown]
# ## Boyce-Codd Normal Form (BCNF)
#
# A relation R is in BCNF (sometimes called 3.5NF) if for every non-trivial functional dependency X->B, X is a superkey of R. A superkey is a set of attributes that can uniquely identify each row in R. (Note a trivial functional dependency is of the form X->Y where Y is a subset of X.)
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/DtlJbZRNvYZu2rDoXZAgRYKX.png" alt="" style="max-width:100%;width:412px;height:auto;"></div>
#
# SSN determines name and age but not phone. SSN alone is not a superkey. Split as follows:
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/ewYgqtMYoxZ2mgRBPNgyxhm3.png" alt="" style="max-width:100%;width:297px;height:auto;"></div>

# %% [markdown]
# ## Fourth and Fifth Normal Form (4NF and 5NF)
#
# Typically, either 3NF or BCNF is good enough for preventing insertion, update, and deletion anomalies.
#
# However, there are additional normal forms:
#
# - 4NF: 3NF + "a record type should not contain two or more independent multi-valued facts about an entity"
#   - see [pizza example on wikipedia](https://en.wikipedia.org/wiki/Fourth_normal_form)
#   - usually the answer is to split into two or more tables
# - [5NF](https://en.wikipedia.org/wiki/Fifth_normal_form): 4NF + "information content cannot be reconstructed from several smaller record types, i.e., from record types each having fewer fields than the original record"

# %% [markdown]
# ## 4NF
#
# Here the goal is to eliminate independent multivalued facts about an entity that are stored in the same table. In the following table from Kent's paper, Smith's ability to cook or type has nothing to do with their ability to speak one of these three languages.
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/DKcJ1Z9PrqQSb5aqaXMaqdeo.png" alt="" style="max-width:100%;width:276px;height:auto;"></div>
#
# So it makes sense to split it into these two tables:
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/gCHpCrktcq3LjssB8Spi4JpH.png" alt="" style="max-width:100%;width:242px;height:auto;"></div>

# %% [markdown]
# ## 5NF
#
# Here the goal is to transform the data in a larger table into smaller tables in cases when the larger table can be reconstructed from the smaller tables.
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/hnvbWgr8JyisXKEr41BrRNUK.png" alt="" style="max-width:100%;width:242px;height:auto;"></div>
#
# Consider the rule: if an agent sells a certain product and they represent a company that makes that product, then they sell that product for that company. If this rule holds, then the table above can be broken into three tables as follows:
#
# <div style="text-align:center;margin:0.4em 0;"><img src="images/QuXXI8V8sd8kprGXBkHigxwc.png" alt="" style="max-width:100%;width:232px;height:auto;"></div>

# %% [markdown]
# ## Types of Normalization
#
# - 1NF
# - 2NF
# - 3NF
# - BCNF (Boyce-Codd Normal Form)
# - 4NF
# - ETNF (Essential Tuple Normal Form)
# - 5NF
# - DKNF (Domain Key Normal Form)
# - 6NF

# %% [markdown]
# <div style="
#     background:#f3ecfa;border:2px solid #57068c;border-radius:14px;
#     padding:1.8em 2em;text-align:center;">
#   <div style="font-size:0.62em;letter-spacing:0.18em;text-transform:uppercase;
#               color:#57068c;font-weight:800;">End of Lecture 26</div>
#   <div style="font-size:1.15em;font-weight:800;color:#3a0460;margin-top:0.4em;">
#     Relational Database Normalization
#   </div>
# </div>
